# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.metrics import roc_auc_score,classification_report,accuracy_score
from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import train_test_split
import eli5
from eli5.sklearn import PermutationImportance
from pdpbox.pdp import pdp_plot,pdp_isolate

# %%
#Loading the supreme court database
#data = pd.read_csv('data/SCDB_2018_02_caseCentered_Citation.csv',encoding='ISO 8859-1')
data = pd.read_csv('../data/SCDB_2019_01_caseCentered_Citation.csv',encoding='ISO 8859-1')
data.shape
# Out:
# (8966, 53)

# %%
#if AdminAction value is 117 in AdminAction if the action has been taken by State Agency
#creating this variables before normalising null values
data['is_adminAction'] = data['adminAction'].isna().astype(int)
data['is_adminActionState']=data['adminActionState'].isna().astype(int)
data['case_argued']=(data['dateArgument'].isnull()).astype(int)
data['case_reargued']=(data['dateRearg'].isnull()).astype(int)

# %%
#Selecting all float columns, they should have been int cols, due to Null values they are designated as Float columns
float_columns = data.select_dtypes('float64').columns
#Replacing all null values with 9999 to convert the float columns to Int
data[float_columns] = data[float_columns].fillna(-1)
for col in float_columns:
    data[col] = data[col].astype('int')

# %%
court_dict = {
    
        -1: 'Not Applicable',
        48: 'California Central U.S. District Court',
        50: 'California Northern U.S. District Court',
        51: 'California Southern U.S. District Court',
        55: 'District Of Columbia U.S. District Court',
        58: 'Florida Southern U.S. District Court',
        66: 'Illinois Northern U.S. District Court',
        75: 'Louisiana Eastern U.S. District Court',
        80: 'Massachusetts U.S. District Court',
        81: 'Michigan Eastern U.S. District Court',
        92: 'New Jersey U.S. District Court',
        94: 'New York Eastern U.S. District Court',
        96: 'New York Southern U.S. District Court',
        109: 'Pennsylvania Eastern U.S. District Court',
        301: 'State Appellate Court',
        300: 'State Supreme Court',
        302: 'State Trial Court',
        121: 'Texas Southern U.S. District Court',
        32: 'U.S. Court of Appeals, District of Columbia',
        28: 'U.S. Court of Appeals, Eighth Circuit',
        31: 'U.S. Court of Appeals, Eleventh Circuit',
        8: 'U.S. Court of Appeals, Federal Circuit',
        25: 'U.S. Court of Appeals, Fifth Circuit',
        21: 'U.S. Court of Appeals, First Circuit',
        24: 'U.S. Court of Appeals, Fourth Circuit',
        29: 'U.S. Court of Appeals, Ninth Circuit',
        22: 'U.S. Court of Appeals, Second Circuit',
        27: 'U.S. Court of Appeals, Seventh Circuit',
        26: 'U.S. Court of Appeals, Sixth Circuit',
        30: 'U.S. Court of Appeals, Tenth Circuit',
        23: 'U.S. Court of Appeals, Third Circuit',
        3: 'U.S. Court of Claims, Court of Federal Claims',
        9: 'U.S. Tax Court',
        126: 'Virginia Eastern U.S. District Court',
        9999:'Other Courts'
                                }

# %%
#updatining caseOrigin with court dict values, other values will be replaced with 9999
data['caseOrigin']=data['caseOrigin'].apply(lambda x: x if x in court_dict.keys() else 9999)
#updatining caseSource with court dict values, other values will be replaced with 9999
data['caseSource']=data['caseSource'].apply(lambda x: x if x in court_dict.keys() else 9999)

# %%
#updatining petitioner with top 15 values, other values will be replaced with 9999
petition_category = data['petitioner'].value_counts(ascending=False)[:15].index.values
data['petitioner']=data['petitioner'].apply(lambda x: x if x in petition_category else 9999)
#updatining respondent with top 15 values, other values will be replaced with 9999
respondent_category = data['respondent'].value_counts(ascending=False)[:15].index.values
data['respondent']=data['respondent'].apply(lambda x: x if x in petition_category else 9999)

# %%
#Separating the variables based on data from the codebook
identity_variables = ['caseId', 'docketId', 'caseIssuesId', 'voteId', 'usCite','sctCite', 'ledCite',
                      'lexisCite', 'docket','caseName']

#Removing following variable from background
#adminAction and  adminActionState, being replaced with boolean features 
background_variables=['petitioner', 'petitionerState', 'respondent', 'respondentState','jurisdiction', 
                      'threeJudgeFdc', 'caseOrigin', 'caseOriginState',
                      'caseSource', 'caseSourceState','lcDisagreement', 'certReason', 'lcDisposition','issueArea']

outcome_variables = ['decisionType','declarationUncon','caseDisposition','caseDispositionUnusual',
                     'precedentAlteration','partyWinning']
vote_variables =['voteUnclear','majVotes','minVotes']

# %%
#Conveting date columns to date format
date_columns = ['dateArgument','dateRearg','dateDecision']
for col in date_columns:
    data[col]=pd.to_datetime(data[col],errors='coerce')

# %%
parties_labels = {9999: 'Others',
                 28: 'State',
                 27: 'United States',
                 100: 'Person accused of crime',
                 126: 'Person convicted of crime',
                 19: 'Govt Official',
                 145: 'Employee',
                 151: 'Employer',
                 249: 'Union',
                 8: 'Govt Employee',
                 3: 'City,Town or Govt Unit',
                 106: 'Alien',
                 215: 'Prisoner',
                 382: 'Labor Board',
                 195: 'Owner',
                 240: 'Taxpayer'}

# %%
    lc_disposition_dict={1:'stay, petition, or motion granted',
                            2:'affirmed',
                            3:'reversed',
                            4:'reversed and remanded',
                            5:'vacated and remanded',
                            6:'affirmed and reversed (or vacated) in part',
                            7:'affirmed and reversed (or vacated) in part and remanded',
                            8:'vacated',
                            9:'petition denied or appeal dismissed',
                            10:'modify',
                            11:'remand',
                            12:'unusual disposition'}

# %%
cert_labels_dict={1: 'case did not arise on cert or cert not granted',
 2: 'federal court conflict',
 3: 'federal court conflict and to resolve important or significant question',
 4: 'putative conflict',
 5: 'conflict between federal court and state court',
 6: 'state court conflict',
 7: 'federal court confusion or uncertainty',
 8: 'state court confusion or uncertainty',
 9: 'federal court and state court confusion or uncertainty',
 10: 'to resolve important or significant question',
 11: 'to resolve question presented',
 12: 'no reason given',
 13: 'other reason'}

# %%
jurisdiction_dict = {1: 'cert',
                    2: 'appeal',
                    3: 'bail',
                    4: 'certification',
                    5: 'docketing fee',
                    6: 'rehearing or restored to calendar for reargument',
                    7: 'injunction',
                    8: 'mandamus',
                    9: 'original',
                    10: 'prohibition',
                    12: 'stay',
                    13: 'writ of error',
                    14: 'writ of habeas corpus',
                    15: 'unspecified, other'    
}

# %%
#Sorting the data based on decisiondate - Useful for generating features
data = data.sort_values('dateDecision').reset_index(drop=True)

# %%
#Removing unspecified  and decisions with null valuesfrom the database
data = data[data['partyWinning'].isin([0,1])]
data.shape
#19 rows have been removed
# Out:
# (8947, 57)

# %%
#majority class base prediction is
data['partyWinning'].value_counts(normalize=True)
#64% is base line prediction
# Out:
# 1    0.639656
# 0    0.360344
# Name: partyWinning, dtype: float64

# %%
#Getting the ROC value for baseline prediction
y_pred = np.ones(len(data))
y_true = data['partyWinning'].values
roc_auc_score(y_true,y_pred)
# Out:
# 0.5

# %%
new_features = ['case_argued','case_reargued','is_adminAction','is_adminActionState','argued_since','reargued_since']

# %%
# prev_vote_variables = ['prev_'+item for item in vote_variables]
# prev_outcome_variables = ['prev_'+item for item in outcome_variables]
# #From previous same issue what was the decision and voting data 
# data[prev_vote_variables] = data.groupby('issueArea')[vote_variables].shift(1)
# data[prev_outcome_variables] = data.groupby('issueArea')[outcome_variables].shift(1)
#data['prev_votes']=data['prev_majVotes']+data['prev_minVotes']

# %%
data['argued_since'] = (data['dateDecision']-data['dateArgument']).dt.days
data['reargued_since'] = (data['dateDecision']-data['dateRearg']).dt.days
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     122     if result is None:
# --> 123         result = _evaluate_standard(op, op_str, a, b)
#     124
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      67     with np.errstate(all='ignore'):
# ---> 68         return op(a, b)
#      69
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in rsub(left, right)
#     147 def rsub(left, right):
# --> 148     return right - left
#     149
#
# TypeError: ufunc subtract cannot use operands with types dtype('<M8[ns]') and dtype('O')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1528             with np.errstate(all='ignore'):
# -> 1529                 return na_op(lvalues, rvalues)
#    1530         except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1506         except TypeError:
# -> 1507             result = masked_arith_op(x, y, op)
#    1508
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in masked_arith_op(x, y, op)
#    1008                 result[mask] = op(xrav[mask],
# -> 1009                                   com.values_from_object(yrav[mask]))
#    1010
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in rsub(left, right)
#     147 def rsub(left, right):
# --> 148     return right - left
#     149
#
# TypeError: ufunc subtract cannot use operands with types dtype('<M8[ns]') and dtype('O')
#
# During handling of the above exception, another exception occurred:
#
# NullFrequencyError                        Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in dispatch_to_index_op(op, left, right, index_class)
#    1190     try:
# -> 1191         result = op(left_idx, right)
#    1192     except NullFrequencyError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(left, right)
#    1582
# -> 1583         result = safe_na_op(lvalues, rvalues)
#    1584         return construct_result(left, result,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1532                 return libalgos.arrmap_object(lvalues,
# -> 1533                                               lambda x: op(x, rvalues))
#    1534             raise
#
# pandas/_libs/algos.pyx in pandas._libs.algos.arrmap()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in <lambda>(x)
#    1532                 return libalgos.arrmap_object(lvalues,
# -> 1533                                               lambda x: op(x, rvalues))
#    1534             raise
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in rsub(left, right)
#     147 def rsub(left, right):
# --> 148     return right - left
#     149
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/datetimelike.py in __sub__(self, other)
#     500             # dispatch to ExtensionArray implementation
# --> 501             result = self._data.__sub__(maybe_unwrap_index(other))
#     502             return wrap_arithmetic_op(self, other, result)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimelike.py in __sub__(self, other)
#    1260                 maybe_integer_op_deprecated(self)
# -> 1261             result = self._time_shift(-other)
#    1262
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimelike.py in _time_shift(self, periods, freq)
#    1166         if self.freq is None:
# -> 1167             raise NullFrequencyError("Cannot shift with no freq")
#    1168
#
# NullFrequencyError: Cannot shift with no freq
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-211-899a35200145> in <module>
# ----> 1 data['argued_since'] = (data['dateDecision']-data['dateArgument']).dt.days
#       2 data['reargued_since'] = (data['dateDecision']-data['dateRearg']).dt.days
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(left, right)
#    1550             # test_dt64_series_add_intlike, which the index dispatching handles
#    1551             # specifically.
# -> 1552             result = dispatch_to_index_op(op, left, right, pd.DatetimeIndex)
#    1553             return construct_result(left, result,
#    1554                                     index=left.index, name=res_name,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in dispatch_to_index_op(op, left, right, index_class)
#    1194         # on add/sub of integers (or int-like).  We re-raise as a TypeError.
#    1195         raise TypeError('incompatible type for a datetime/timedelta '
# -> 1196                         'operation [{name}]'.format(name=op.__name__))
#    1197     return result
#    1198
#
# TypeError: incompatible type for a datetime/timedelta operation [sub]

# %%
data['argued_since'].hist()

# %%
def arguedays(row):
    if(row['dateArgument'] !=None):
        return (row['dateDecision']-row['dateArgument'])
    else:
       return 0

# %%
data.apply(arguedays,axis=1).describe()
# Out:
# count                       7908
# mean     90 days 02:53:32.139605
# std      65 days 16:44:34.072799
# min          -104 days +00:00:00
# 25%             52 days 00:00:00
# 50%             76 days 00:00:00
# 75%            112 days 00:00:00
# max            799 days 00:00:00
# dtype: object

# %%
data['reargued_since'].describe()
# Out:
# count    178.000000
# mean     111.393258
# std       84.870272
# min        7.000000
# 25%       56.250000
# 50%       98.000000
# 75%      145.500000
# max      665.000000
# Name: reargued_since, dtype: float64

# %%
pd.qcut(data['argued_since'],5,labels=[1,2,3,4,5])
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       1
# 5       1
# 6       5
# 7       1
# 8       1
# 9       1
# 10      2
# 11      5
# 12      2
# 13      2
# 14      5
# 15      1
# 16      1
# 17      5
# 18      1
# 19      1
# 20      1
# 21      1
# 22      5
# 23      5
# 24      1
# 25      2
# 26      1
# 27      1
# 28      1
# 29      2
#        ..
# 8936    5
# 8937    1
# 8938    5
# 8939    1
# 8940    4
# 8941    1
# 8942    2
# 8943    4
# 8944    5
# 8945    5
# 8946    4
# 8947    4
# 8948    2
# 8949    3
# 8950    5
# 8951    4
# 8952    3
# 8953    2
# 8954    4
# 8955    1
# 8956    3
# 8957    2
# 8958    3
# 8959    4
# 8960    5
# 8961    4
# 8962    4
# 8963    3
# 8964    3
# 8965    4
# Name: argued_since, Length: 8947, dtype: category
# Categories (5, int64): [1 < 2 < 3 < 4 < 5]

# %%
data = data.fillna(-1)

# %%
data['argued_since']=pd.qcut(data['argued_since'],5,labels=[1,2,3,4,5],duplicates='drop')
#data['reargued_since']=pd.qcut(data['reargued_since'],5,labels=[1,2,3,4],duplicates='drop')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-210-28aaade7271c> in <module>
# ----> 1 data['argued_since']=pd.qcut(data['argued_since'],5,labels=[1,2,3,4,5],duplicates='drop')
#       2 #data['reargued_since']=pd.qcut(data['reargued_since'],5,labels=[1,2,3,4],duplicates='drop')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/tile.py in qcut(x, q, labels, retbins, precision, duplicates)
#     311     fac, bins = _bins_to_cuts(x, bins, labels=labels,
#     312                               precision=precision, include_lowest=True,
# --> 313                               dtype=dtype, duplicates=duplicates)
#     314
#     315     return _postprocess_for_cut(fac, bins, retbins, x_is_series,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     357         else:
#     358             if len(labels) != len(bins) - 1:
# --> 359                 raise ValueError('Bin labels must be one fewer than '
#     360                                  'the number of bin edges')
#     361         if not is_categorical_dtype(labels):
#
# ValueError: Bin labels must be one fewer than the number of bin edges

# %%
#Setting a basic model to fit the data
target = 'partyWinning'
features = background_variables+new_features

# %%
testsize = 1000
test = data[-testsize:]
val = data[-testsize*2:-testsize]
train = data[:-testsize*2]
test.shape,val.shape,train.shape
# Out:
# ((1000, 59), (1000, 59), (6947, 59))

# %%
train[target].value_counts(normalize=True),val[target].value_counts(normalize=True),test[target].value_counts(normalize=True)
# Out:
# (1    0.63495
#  0    0.36505
#  Name: partyWinning, dtype: float64, 1    0.635
#  0    0.365
#  Name: partyWinning, dtype: float64, 1    0.677
#  0    0.323
#  Name: partyWinning, dtype: float64)

# %%
train = train.fillna(-1)
test = test.fillna(-1)
val = val.fillna(-1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-200-57b29b2e0e7d> in <module>
# ----> 1 train = train.fillna(-1)
#       2 test = test.fillna(-1)
#       3 val = val.fillna(-1)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in fillna(self, value, method, axis, inplace, limit, downcast, **kwargs)
#    4032                      self).fillna(value=value, method=method, axis=axis,
#    4033                                   inplace=inplace, limit=limit,
# -> 4034                                   downcast=downcast, **kwargs)
#    4035
#    4036     @Appender(_shared_docs['replace'] % _shared_doc_kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    6121                 new_data = self._data.fillna(value=value, limit=limit,
#    6122                                              inplace=inplace,
# -> 6123                                              downcast=downcast)
#    6124             elif isinstance(value, DataFrame) and self.ndim == 2:
#    6125                 new_data = self.where(self.notna(), value)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in fillna(self, **kwargs)
#     523
#     524     def fillna(self, **kwargs):
# --> 525         return self.apply('fillna', **kwargs)
#     526
#     527     def downcast(self, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in fillna(self, value, limit, inplace, downcast)
#    1832     def fillna(self, value, limit=None, inplace=False, downcast=None):
#    1833         values = self.values if inplace else self.values.copy()
# -> 1834         values = values.fillna(value=value, limit=limit)
#    1835         return [self.make_block_same_class(values=values,
#    1836                                            placement=self.mgr_locs,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/categorical.py in fillna(self, value, method, limit)
#    1782             elif is_hashable(value):
#    1783                 if not isna(value) and value not in self.categories:
# -> 1784                     raise ValueError("fill value must be in categories")
#    1785
#    1786                 mask = codes == -1
#
# ValueError: fill value must be in categories

# %%
X_test = test[features]
y_test = test[target]
X_val = val[features]
y_val = val[target]
X_train = train[features]
y_train = train[target]

# %%
len(features)
# Out:
# 20

# %%
rfc = RandomForestClassifier(n_estimators=1000,random_state=31,min_samples_split=5,max_depth=10)
rfc.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-202-e85a7187e820> in <module>
#       1 rfc = RandomForestClassifier(n_estimators=1000,random_state=31,min_samples_split=5,max_depth=10)
# ----> 2 rfc.fit(X_train,y_train)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     247
#     248         # Validate or convert input data
# --> 249         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     250         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     251         if sample_weight is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     494             try:
#     495                 warnings.simplefilter('error', ComplexWarning)
# --> 496                 array = np.asarray(array, dtype=dtype, order=order)
#     497             except ComplexWarning:
#     498                 raise ValueError("Complex data not supported\n"
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# TypeError: float() argument must be a string or a number, not 'pandas._libs.interval.Interval'

# %%
print("ROC score for Train is:",roc_auc_score(y_train,rfc.predict_proba(X_train)[:,1]))
print("ROC score for Val is:",roc_auc_score(y_val,rfc.predict_proba(X_val)[:,1]))
print("ROC score for Test is:",roc_auc_score(y_test,rfc.predict_proba(X_test)[:,1]))
print("Accuracy score for Train is:",accuracy_score(y_train,rfc.predict(X_train)))
print("Accuracy score for Val is:",accuracy_score(y_val,rfc.predict(X_val)))
print("Accuracy score for Test is:",accuracy_score(y_test,rfc.predict(X_test)))
# Out:
# ROC score for Train is: 0.8546961836160961
# ROC score for Val is: 0.6660942724625175
# ROC score for Test is: 0.6605288309835324
# Accuracy score for Train is: 0.7370087807686772
# Accuracy score for Val is: 0.666
# Accuracy score for Test is: 0.672

# %%
# ROC score for Train is: 0.8763873671857065
# ROC score for Val is: 0.6722295329522165
# ROC score for Test is: 0.6508521934778732
# Accuracy score for Train is: 0.7475169137757305
# Accuracy score for Val is: 0.655
# Accuracy score for Test is: 0.672

# ROC score for Train is: 0.859208892738043
# ROC score for Val is: 0.6656455614281092
# ROC score for Test is: 0.6575563289142137
# Accuracy score for Train is: 0.742046926730963
# Accuracy score for Val is: 0.668
# Accuracy score for Test is: 0.669

# %%
from xgboost import XGBClassifier
xgboost = XGBClassifier(n_estimators=1000,learning_rate=0.02,objective='binary:logistic',max_depth=5,min_samples_split=5,random_state=31)
xgboost.fit(X_train,y_train,eval_metric='auc',eval_set=[(X_train,y_train),(X_val,y_val)],early_stopping_rounds=250)
# Out:
# [0]	validation_0-auc:0.651321	validation_1-auc:0.604761
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 250 rounds.
# [1]	validation_0-auc:0.657806	validation_1-auc:0.622168
# [2]	validation_0-auc:0.65672	validation_1-auc:0.614553
# [3]	validation_0-auc:0.659421	validation_1-auc:0.622254
# [4]	validation_0-auc:0.659775	validation_1-auc:0.622901
# [5]	validation_0-auc:0.659188	validation_1-auc:0.624213
# [6]	validation_0-auc:0.666257	validation_1-auc:0.628079
# [7]	validation_0-auc:0.669068	validation_1-auc:0.633097
# [8]	validation_0-auc:0.670722	validation_1-auc:0.633599
# [9]	validation_0-auc:0.670271	validation_1-auc:0.634039
# [10]	validation_0-auc:0.671911	validation_1-auc:0.637459
# [11]	validation_0-auc:0.673519	validation_1-auc:0.63805
# [12]	validation_0-auc:0.673153	validation_1-auc:0.636449
# [13]	validation_0-auc:0.676146	validation_1-auc:0.638602
# [14]	validation_0-auc:0.676655	validation_1-auc:0.640149
# [15]	validation_0-auc:0.676733	validation_1-auc:0.640453
# [16]	validation_0-auc:0.677402	validation_1-auc:0.640811
# [17]	validation_0-auc:0.67894	validation_1-auc:0.64217
# [18]	validation_0-auc:0.680166	validation_1-auc:0.642248
# [19]	validation_0-auc:0.681315	validation_1-auc:0.641245
# [20]	validation_0-auc:0.682326	validation_1-auc:0.64162
# [21]	validation_0-auc:0.682495	validation_1-auc:0.642134
# [22]	validation_0-auc:0.682886	validation_1-auc:0.642388
# [23]	validation_0-auc:0.684041	validation_1-auc:0.642712
# [24]	validation_0-auc:0.684877	validation_1-auc:0.641903
# [25]	validation_0-auc:0.686022	validation_1-auc:0.642785
# [26]	validation_0-auc:0.686867	validation_1-auc:0.641538
# [27]	validation_0-auc:0.687743	validation_1-auc:0.642039
# [28]	validation_0-auc:0.688619	validation_1-auc:0.641279
# [29]	validation_0-auc:0.688635	validation_1-auc:0.640438
# [30]	validation_0-auc:0.688419	validation_1-auc:0.640772
# [31]	validation_0-auc:0.687957	validation_1-auc:0.641407
# [32]	validation_0-auc:0.687875	validation_1-auc:0.641081
# [33]	validation_0-auc:0.687814	validation_1-auc:0.641383
# [34]	validation_0-auc:0.68775	validation_1-auc:0.641674
# [35]	validation_0-auc:0.687943	validation_1-auc:0.642002
# [36]	validation_0-auc:0.688287	validation_1-auc:0.64219
# [37]	validation_0-auc:0.68829	validation_1-auc:0.643048
# [38]	validation_0-auc:0.688513	validation_1-auc:0.643286
# [39]	validation_0-auc:0.688565	validation_1-auc:0.644541
# [40]	validation_0-auc:0.688709	validation_1-auc:0.64266
# [41]	validation_0-auc:0.688865	validation_1-auc:0.644541
# [42]	validation_0-auc:0.688703	validation_1-auc:0.644478
# [43]	validation_0-auc:0.688771	validation_1-auc:0.644056
# [44]	validation_0-auc:0.689602	validation_1-auc:0.644601
# [45]	validation_0-auc:0.690096	validation_1-auc:0.644934
# [46]	validation_0-auc:0.690805	validation_1-auc:0.645443
# [47]	validation_0-auc:0.691275	validation_1-auc:0.645501
# [48]	validation_0-auc:0.692542	validation_1-auc:0.644947
# [49]	validation_0-auc:0.692474	validation_1-auc:0.645208
# [50]	validation_0-auc:0.692825	validation_1-auc:0.645177
# [51]	validation_0-auc:0.69419	validation_1-auc:0.644045
# [52]	validation_0-auc:0.695944	validation_1-auc:0.643311
# [53]	validation_0-auc:0.696793	validation_1-auc:0.643238
# [54]	validation_0-auc:0.697245	validation_1-auc:0.642996
# [55]	validation_0-auc:0.69942	validation_1-auc:0.643018
# [56]	validation_0-auc:0.699816	validation_1-auc:0.643704
# [57]	validation_0-auc:0.699837	validation_1-auc:0.643301
# [58]	validation_0-auc:0.70056	validation_1-auc:0.642412
# [59]	validation_0-auc:0.701932	validation_1-auc:0.642884
# [60]	validation_0-auc:0.702309	validation_1-auc:0.642362
# [61]	validation_0-auc:0.703954	validation_1-auc:0.642373
# [62]	validation_0-auc:0.704283	validation_1-auc:0.641911
# [63]	validation_0-auc:0.704728	validation_1-auc:0.64211
# [64]	validation_0-auc:0.706661	validation_1-auc:0.641644
# [65]	validation_0-auc:0.706798	validation_1-auc:0.642034
# [66]	validation_0-auc:0.708244	validation_1-auc:0.64187
# [67]	validation_0-auc:0.708545	validation_1-auc:0.641944
# [68]	validation_0-auc:0.709055	validation_1-auc:0.641372
# [69]	validation_0-auc:0.709156	validation_1-auc:0.641542
# [70]	validation_0-auc:0.710227	validation_1-auc:0.642403
# [71]	validation_0-auc:0.710503	validation_1-auc:0.642123
# [72]	validation_0-auc:0.710642	validation_1-auc:0.64225
# [73]	validation_0-auc:0.711234	validation_1-auc:0.642548
# [74]	validation_0-auc:0.711553	validation_1-auc:0.642345
# [75]	validation_0-auc:0.71193	validation_1-auc:0.642254
# [76]	validation_0-auc:0.713217	validation_1-auc:0.642852
# [77]	validation_0-auc:0.713647	validation_1-auc:0.643441
# [78]	validation_0-auc:0.713799	validation_1-auc:0.64376
# [79]	validation_0-auc:0.714678	validation_1-auc:0.644198
# [80]	validation_0-auc:0.715956	validation_1-auc:0.644064
# [81]	validation_0-auc:0.716225	validation_1-auc:0.644179
# [82]	validation_0-auc:0.716777	validation_1-auc:0.644332
# [83]	validation_0-auc:0.717672	validation_1-auc:0.644686
# [84]	validation_0-auc:0.717896	validation_1-auc:0.645113
# [85]	validation_0-auc:0.718576	validation_1-auc:0.645477
# [86]	validation_0-auc:0.719623	validation_1-auc:0.645894
# [87]	validation_0-auc:0.720142	validation_1-auc:0.645639
# [88]	validation_0-auc:0.720397	validation_1-auc:0.645074
# [89]	validation_0-auc:0.721227	validation_1-auc:0.645637
# [90]	validation_0-auc:0.72173	validation_1-auc:0.645723
# [91]	validation_0-auc:0.722231	validation_1-auc:0.645935
# [92]	validation_0-auc:0.723058	validation_1-auc:0.64628
# [93]	validation_0-auc:0.72398	validation_1-auc:0.64678
# [94]	validation_0-auc:0.724395	validation_1-auc:0.646901
# [95]	validation_0-auc:0.724548	validation_1-auc:0.646547
# [96]	validation_0-auc:0.725412	validation_1-auc:0.646964
# [97]	validation_0-auc:0.725734	validation_1-auc:0.647207
# [98]	validation_0-auc:0.726572	validation_1-auc:0.647147
# [99]	validation_0-auc:0.727072	validation_1-auc:0.647572
# [100]	validation_0-auc:0.727358	validation_1-auc:0.647484
# [101]	validation_0-auc:0.727844	validation_1-auc:0.647924
# [102]	validation_0-auc:0.728088	validation_1-auc:0.647747
# [103]	validation_0-auc:0.72874	validation_1-auc:0.647794
# [104]	validation_0-auc:0.729531	validation_1-auc:0.648651
# [105]	validation_0-auc:0.729999	validation_1-auc:0.648858
# [106]	validation_0-auc:0.730418	validation_1-auc:0.648733
# [107]	validation_0-auc:0.730676	validation_1-auc:0.648702
# [108]	validation_0-auc:0.731123	validation_1-auc:0.648862
# [109]	validation_0-auc:0.731912	validation_1-auc:0.649229
# [110]	validation_0-auc:0.732216	validation_1-auc:0.649526
# [111]	validation_0-auc:0.732918	validation_1-auc:0.64996
# [112]	validation_0-auc:0.73336	validation_1-auc:0.650223
# [113]	validation_0-auc:0.733582	validation_1-auc:0.650247
# [114]	validation_0-auc:0.733916	validation_1-auc:0.649841
# [115]	validation_0-auc:0.734624	validation_1-auc:0.650413
# [116]	validation_0-auc:0.734998	validation_1-auc:0.650195
# [117]	validation_0-auc:0.735897	validation_1-auc:0.650251
# [118]	validation_0-auc:0.736316	validation_1-auc:0.650553
# [119]	validation_0-auc:0.736411	validation_1-auc:0.651075
# [120]	validation_0-auc:0.736859	validation_1-auc:0.651472
# [121]	validation_0-auc:0.737083	validation_1-auc:0.651317
# [122]	validation_0-auc:0.737359	validation_1-auc:0.651723
# [123]	validation_0-auc:0.737541	validation_1-auc:0.651824
# [124]	validation_0-auc:0.738228	validation_1-auc:0.65171
# [125]	validation_0-auc:0.73929	validation_1-auc:0.65174
# [126]	validation_0-auc:0.739412	validation_1-auc:0.651863
# [127]	validation_0-auc:0.740487	validation_1-auc:0.651867
# [128]	validation_0-auc:0.741394	validation_1-auc:0.651539
# [129]	validation_0-auc:0.741707	validation_1-auc:0.651748
# [130]	validation_0-auc:0.742471	validation_1-auc:0.6516
# [131]	validation_0-auc:0.742578	validation_1-auc:0.65182
# [132]	validation_0-auc:0.74348	validation_1-auc:0.65182
# [133]	validation_0-auc:0.743609	validation_1-auc:0.651789
# [134]	validation_0-auc:0.744267	validation_1-auc:0.652122
# [135]	validation_0-auc:0.745042	validation_1-auc:0.652087
# [136]	validation_0-auc:0.745125	validation_1-auc:0.652242
# [137]	validation_0-auc:0.745856	validation_1-auc:0.652242
# [138]	validation_0-auc:0.746617	validation_1-auc:0.651943
# [139]	validation_0-auc:0.74698	validation_1-auc:0.652219
# [140]	validation_0-auc:0.747062	validation_1-auc:0.652262
# [141]	validation_0-auc:0.747731	validation_1-auc:0.652499
# [142]	validation_0-auc:0.748304	validation_1-auc:0.653026
# [143]	validation_0-auc:0.748348	validation_1-auc:0.653397
# [144]	validation_0-auc:0.748692	validation_1-auc:0.653724
# [145]	validation_0-auc:0.749556	validation_1-auc:0.654221
# [146]	validation_0-auc:0.749985	validation_1-auc:0.654536
# [147]	validation_0-auc:0.750042	validation_1-auc:0.654587
# [148]	validation_0-auc:0.750744	validation_1-auc:0.65492
# [149]	validation_0-auc:0.751069	validation_1-auc:0.655286
# [150]	validation_0-auc:0.75157	validation_1-auc:0.655122
# [151]	validation_0-auc:0.751871	validation_1-auc:0.655368
# [152]	validation_0-auc:0.751912	validation_1-auc:0.655459
# [153]	validation_0-auc:0.752505	validation_1-auc:0.655235
# [154]	validation_0-auc:0.752907	validation_1-auc:0.655571
# [155]	validation_0-auc:0.753157	validation_1-auc:0.655731
# [156]	validation_0-auc:0.753709	validation_1-auc:0.655992
# [157]	validation_0-auc:0.754295	validation_1-auc:0.655962
# [158]	validation_0-auc:0.75434	validation_1-auc:0.656108
# [159]	validation_0-auc:0.754878	validation_1-auc:0.655871
# [160]	validation_0-auc:0.755261	validation_1-auc:0.656065
# [161]	validation_0-auc:0.755275	validation_1-auc:0.656169
# [162]	validation_0-auc:0.755629	validation_1-auc:0.655832
# [163]	validation_0-auc:0.755909	validation_1-auc:0.655573
# [164]	validation_0-auc:0.756193	validation_1-auc:0.655772
# [165]	validation_0-auc:0.756194	validation_1-auc:0.655742
# [166]	validation_0-auc:0.756644	validation_1-auc:0.655509
# [167]	validation_0-auc:0.756863	validation_1-auc:0.655793
# [168]	validation_0-auc:0.757196	validation_1-auc:0.656208
# [169]	validation_0-auc:0.757326	validation_1-auc:0.655998
# [170]	validation_0-auc:0.757887	validation_1-auc:0.655959
# [171]	validation_0-auc:0.757887	validation_1-auc:0.655946
# [172]	validation_0-auc:0.758193	validation_1-auc:0.655994
# [173]	validation_0-auc:0.758685	validation_1-auc:0.656149
# [174]	validation_0-auc:0.758896	validation_1-auc:0.656292
# [175]	validation_0-auc:0.759211	validation_1-auc:0.656154
# [176]	validation_0-auc:0.759278	validation_1-auc:0.656175
# [177]	validation_0-auc:0.7595	validation_1-auc:0.656326
# [178]	validation_0-auc:0.759655	validation_1-auc:0.656525
# [179]	validation_0-auc:0.760106	validation_1-auc:0.656469
# [180]	validation_0-auc:0.760549	validation_1-auc:0.656503
# [181]	validation_0-auc:0.760727	validation_1-auc:0.656546
# [182]	validation_0-auc:0.760707	validation_1-auc:0.656615
# [183]	validation_0-auc:0.76072	validation_1-auc:0.656469
# [184]	validation_0-auc:0.760959	validation_1-auc:0.656814
# [185]	validation_0-auc:0.761241	validation_1-auc:0.656887
# [186]	validation_0-auc:0.761694	validation_1-auc:0.656788
# [187]	validation_0-auc:0.761902	validation_1-auc:0.65671
# [188]	validation_0-auc:0.762243	validation_1-auc:0.656695
# [189]	validation_0-auc:0.762409	validation_1-auc:0.656576
# [190]	validation_0-auc:0.762612	validation_1-auc:0.656391
# [191]	validation_0-auc:0.76283	validation_1-auc:0.656412
# [192]	validation_0-auc:0.76311	validation_1-auc:0.656503
# [193]	validation_0-auc:0.763154	validation_1-auc:0.656581
# [194]	validation_0-auc:0.763341	validation_1-auc:0.656542
# [195]	validation_0-auc:0.763479	validation_1-auc:0.656637
# [196]	validation_0-auc:0.763866	validation_1-auc:0.656784
# [197]	validation_0-auc:0.764074	validation_1-auc:0.656555
# [198]	validation_0-auc:0.764041	validation_1-auc:0.656563
# [199]	validation_0-auc:0.764199	validation_1-auc:0.656395
# [200]	validation_0-auc:0.764323	validation_1-auc:0.656412
# [201]	validation_0-auc:0.764445	validation_1-auc:0.656404
# [202]	validation_0-auc:0.764455	validation_1-auc:0.656356
# [203]	validation_0-auc:0.764644	validation_1-auc:0.656421
# [204]	validation_0-auc:0.764787	validation_1-auc:0.656434
# [205]	validation_0-auc:0.765206	validation_1-auc:0.656816
# [206]	validation_0-auc:0.765417	validation_1-auc:0.656825
# [207]	validation_0-auc:0.76567	validation_1-auc:0.656635
# [208]	validation_0-auc:0.765826	validation_1-auc:0.656445
# [209]	validation_0-auc:0.765928	validation_1-auc:0.656328
# [210]	validation_0-auc:0.766157	validation_1-auc:0.656294
# [211]	validation_0-auc:0.766259	validation_1-auc:0.65632
# [212]	validation_0-auc:0.766379	validation_1-auc:0.656268
# [213]	validation_0-auc:0.766574	validation_1-auc:0.656264
# [214]	validation_0-auc:0.766824	validation_1-auc:0.656402
# [215]	validation_0-auc:0.767015	validation_1-auc:0.656436
# [216]	validation_0-auc:0.767096	validation_1-auc:0.656359
# [217]	validation_0-auc:0.767332	validation_1-auc:0.656121
# [218]	validation_0-auc:0.767626	validation_1-auc:0.656402
# [219]	validation_0-auc:0.767791	validation_1-auc:0.656419
# [220]	validation_0-auc:0.768187	validation_1-auc:0.656523
# [221]	validation_0-auc:0.768336	validation_1-auc:0.656488
# [222]	validation_0-auc:0.768338	validation_1-auc:0.656505
# [223]	validation_0-auc:0.768574	validation_1-auc:0.656583
# [224]	validation_0-auc:0.768948	validation_1-auc:0.656324
# [225]	validation_0-auc:0.768942	validation_1-auc:0.656363
# [226]	validation_0-auc:0.769035	validation_1-auc:0.656371
# [227]	validation_0-auc:0.769162	validation_1-auc:0.656402
# [228]	validation_0-auc:0.76931	validation_1-auc:0.656574
# [229]	validation_0-auc:0.769548	validation_1-auc:0.656557
# [230]	validation_0-auc:0.769656	validation_1-auc:0.656643
# [231]	validation_0-auc:0.769965	validation_1-auc:0.656548
# [232]	validation_0-auc:0.770035	validation_1-auc:0.656471
# [233]	validation_0-auc:0.770394	validation_1-auc:0.65641
# [234]	validation_0-auc:0.770631	validation_1-auc:0.656328
# [235]	validation_0-auc:0.770707	validation_1-auc:0.656514
# [236]	validation_0-auc:0.770772	validation_1-auc:0.65644
# [237]	validation_0-auc:0.770907	validation_1-auc:0.656259
# [238]	validation_0-auc:0.771013	validation_1-auc:0.65619
# [239]	validation_0-auc:0.771181	validation_1-auc:0.656156
# [240]	validation_0-auc:0.771337	validation_1-auc:0.6561
# [241]	validation_0-auc:0.771495	validation_1-auc:0.655992
# [242]	validation_0-auc:0.771583	validation_1-auc:0.656035
# [243]	validation_0-auc:0.771892	validation_1-auc:0.656151
# [244]	validation_0-auc:0.772069	validation_1-auc:0.656354
# [245]	validation_0-auc:0.772218	validation_1-auc:0.656488
# [246]	validation_0-auc:0.772472	validation_1-auc:0.656365
# [247]	validation_0-auc:0.772691	validation_1-auc:0.656255
# [248]	validation_0-auc:0.772775	validation_1-auc:0.656365
# [249]	validation_0-auc:0.772984	validation_1-auc:0.656548
# [250]	validation_0-auc:0.773056	validation_1-auc:0.656497
# [251]	validation_0-auc:0.773289	validation_1-auc:0.656402
# [252]	validation_0-auc:0.773325	validation_1-auc:0.656376
# [253]	validation_0-auc:0.77351	validation_1-auc:0.656453
# [254]	validation_0-auc:0.773623	validation_1-auc:0.65632
# [255]	validation_0-auc:0.773859	validation_1-auc:0.656126
# [256]	validation_0-auc:0.774166	validation_1-auc:0.656384
# [257]	validation_0-auc:0.774281	validation_1-auc:0.6566
# [258]	validation_0-auc:0.774419	validation_1-auc:0.656613
# [259]	validation_0-auc:0.774675	validation_1-auc:0.656825
# [260]	validation_0-auc:0.774872	validation_1-auc:0.657006
# [261]	validation_0-auc:0.775162	validation_1-auc:0.656937
# [262]	validation_0-auc:0.775232	validation_1-auc:0.656825
# [263]	validation_0-auc:0.77548	validation_1-auc:0.656898
# [264]	validation_0-auc:0.77565	validation_1-auc:0.65695
# [265]	validation_0-auc:0.776205	validation_1-auc:0.65696
# [266]	validation_0-auc:0.776513	validation_1-auc:0.657275
# [267]	validation_0-auc:0.776719	validation_1-auc:0.657202
# [268]	validation_0-auc:0.776897	validation_1-auc:0.657137
# [269]	validation_0-auc:0.77714	validation_1-auc:0.657146
# [270]	validation_0-auc:0.777265	validation_1-auc:0.657392
# [271]	validation_0-auc:0.77734	validation_1-auc:0.657521
# [272]	validation_0-auc:0.777519	validation_1-auc:0.657819
# [273]	validation_0-auc:0.777575	validation_1-auc:0.657897
# [274]	validation_0-auc:0.777737	validation_1-auc:0.657871
# [275]	validation_0-auc:0.77788	validation_1-auc:0.657957
# [276]	validation_0-auc:0.778052	validation_1-auc:0.658056
# [277]	validation_0-auc:0.778167	validation_1-auc:0.658298
# [278]	validation_0-auc:0.778328	validation_1-auc:0.658319
# [279]	validation_0-auc:0.778511	validation_1-auc:0.658419
# [280]	validation_0-auc:0.778744	validation_1-auc:0.658436
# [281]	validation_0-auc:0.778823	validation_1-auc:0.658496
# [282]	validation_0-auc:0.778949	validation_1-auc:0.658535
# [283]	validation_0-auc:0.779088	validation_1-auc:0.658578
# [284]	validation_0-auc:0.779219	validation_1-auc:0.658332
# [285]	validation_0-auc:0.779329	validation_1-auc:0.658591
# [286]	validation_0-auc:0.779559	validation_1-auc:0.658678
# [287]	validation_0-auc:0.779739	validation_1-auc:0.658527
# [288]	validation_0-auc:0.780258	validation_1-auc:0.658522
# [289]	validation_0-auc:0.780397	validation_1-auc:0.658544
# [290]	validation_0-auc:0.780495	validation_1-auc:0.658604
# [291]	validation_0-auc:0.780671	validation_1-auc:0.658889
# [292]	validation_0-auc:0.780721	validation_1-auc:0.658902
# [293]	validation_0-auc:0.780783	validation_1-auc:0.658867
# [294]	validation_0-auc:0.781024	validation_1-auc:0.659139
# [295]	validation_0-auc:0.781402	validation_1-auc:0.659295
# [296]	validation_0-auc:0.781498	validation_1-auc:0.659325
# [297]	validation_0-auc:0.781743	validation_1-auc:0.659459
# [298]	validation_0-auc:0.782071	validation_1-auc:0.659355
# [299]	validation_0-auc:0.782467	validation_1-auc:0.659228
# [300]	validation_0-auc:0.782549	validation_1-auc:0.659267
# [301]	validation_0-auc:0.782707	validation_1-auc:0.659167
# [302]	validation_0-auc:0.782897	validation_1-auc:0.659133
# [303]	validation_0-auc:0.783222	validation_1-auc:0.65898
# [304]	validation_0-auc:0.78349	validation_1-auc:0.659085
# [305]	validation_0-auc:0.783663	validation_1-auc:0.658928
# [306]	validation_0-auc:0.783988	validation_1-auc:0.65863
# [307]	validation_0-auc:0.784208	validation_1-auc:0.659053
# [308]	validation_0-auc:0.784284	validation_1-auc:0.659094
# [309]	validation_0-auc:0.78449	validation_1-auc:0.659141
# [310]	validation_0-auc:0.784771	validation_1-auc:0.658757
# [311]	validation_0-auc:0.784933	validation_1-auc:0.659012
# [312]	validation_0-auc:0.785003	validation_1-auc:0.659094
# [313]	validation_0-auc:0.785076	validation_1-auc:0.65896
# [314]	validation_0-auc:0.785309	validation_1-auc:0.659141
# [315]	validation_0-auc:0.78553	validation_1-auc:0.659109
# [316]	validation_0-auc:0.785571	validation_1-auc:0.659271
# [317]	validation_0-auc:0.785764	validation_1-auc:0.659195
# [318]	validation_0-auc:0.786031	validation_1-auc:0.659551
# [319]	validation_0-auc:0.786246	validation_1-auc:0.659713
# [320]	validation_0-auc:0.786536	validation_1-auc:0.659599
# [321]	validation_0-auc:0.786789	validation_1-auc:0.659616
# [322]	validation_0-auc:0.786973	validation_1-auc:0.659551
# [323]	validation_0-auc:0.787324	validation_1-auc:0.659405
# [324]	validation_0-auc:0.787366	validation_1-auc:0.659569
# [325]	validation_0-auc:0.787614	validation_1-auc:0.65962
# [326]	validation_0-auc:0.787677	validation_1-auc:0.659888
# [327]	validation_0-auc:0.787671	validation_1-auc:0.659741
# [328]	validation_0-auc:0.787808	validation_1-auc:0.65972
# [329]	validation_0-auc:0.787873	validation_1-auc:0.659793
# [330]	validation_0-auc:0.788128	validation_1-auc:0.659922
# [331]	validation_0-auc:0.788366	validation_1-auc:0.659823
# [332]	validation_0-auc:0.788546	validation_1-auc:0.659838
# [333]	validation_0-auc:0.788607	validation_1-auc:0.65981
# [334]	validation_0-auc:0.788727	validation_1-auc:0.659704
# [335]	validation_0-auc:0.788808	validation_1-auc:0.659806
# [336]	validation_0-auc:0.789113	validation_1-auc:0.659741
# [337]	validation_0-auc:0.789412	validation_1-auc:0.660155
# [338]	validation_0-auc:0.789493	validation_1-auc:0.660125
# [339]	validation_0-auc:0.789695	validation_1-auc:0.66003
# [340]	validation_0-auc:0.789775	validation_1-auc:0.660065
# [341]	validation_0-auc:0.789965	validation_1-auc:0.660069
# [342]	validation_0-auc:0.790043	validation_1-auc:0.660229
# [343]	validation_0-auc:0.790172	validation_1-auc:0.660337
# [344]	validation_0-auc:0.790404	validation_1-auc:0.660475
# [345]	validation_0-auc:0.790534	validation_1-auc:0.660462
# [346]	validation_0-auc:0.790693	validation_1-auc:0.66025
# [347]	validation_0-auc:0.790751	validation_1-auc:0.660198
# [348]	validation_0-auc:0.79081	validation_1-auc:0.66028
# [349]	validation_0-auc:0.790842	validation_1-auc:0.660419
# [350]	validation_0-auc:0.790921	validation_1-auc:0.660492
# [351]	validation_0-auc:0.791054	validation_1-auc:0.660444
# [352]	validation_0-auc:0.791124	validation_1-auc:0.660436
# [353]	validation_0-auc:0.791402	validation_1-auc:0.660867
# [354]	validation_0-auc:0.791575	validation_1-auc:0.660854
# [355]	validation_0-auc:0.791818	validation_1-auc:0.661048
# [356]	validation_0-auc:0.791923	validation_1-auc:0.661031
# [357]	validation_0-auc:0.791973	validation_1-auc:0.661074
# [358]	validation_0-auc:0.792156	validation_1-auc:0.661182
# [359]	validation_0-auc:0.792326	validation_1-auc:0.661245
# [360]	validation_0-auc:0.792368	validation_1-auc:0.661204
# [361]	validation_0-auc:0.792575	validation_1-auc:0.661281
# [362]	validation_0-auc:0.792758	validation_1-auc:0.661372
# [363]	validation_0-auc:0.792833	validation_1-auc:0.661407
# [364]	validation_0-auc:0.793072	validation_1-auc:0.661432
# [365]	validation_0-auc:0.793187	validation_1-auc:0.661385
# [366]	validation_0-auc:0.793318	validation_1-auc:0.661368
# [367]	validation_0-auc:0.793342	validation_1-auc:0.661359
# [368]	validation_0-auc:0.79358	validation_1-auc:0.661493
# [369]	validation_0-auc:0.793658	validation_1-auc:0.661501
# [370]	validation_0-auc:0.793794	validation_1-auc:0.661454
# [371]	validation_0-auc:0.794002	validation_1-auc:0.661782
# [372]	validation_0-auc:0.794187	validation_1-auc:0.662015
# [373]	validation_0-auc:0.794322	validation_1-auc:0.661985
# [374]	validation_0-auc:0.794416	validation_1-auc:0.661998
# [375]	validation_0-auc:0.794533	validation_1-auc:0.662071
# [376]	validation_0-auc:0.794758	validation_1-auc:0.661959
# [377]	validation_0-auc:0.794885	validation_1-auc:0.662058
# [378]	validation_0-auc:0.795051	validation_1-auc:0.662043
# [379]	validation_0-auc:0.79516	validation_1-auc:0.66203
# [380]	validation_0-auc:0.79518	validation_1-auc:0.66206
# [381]	validation_0-auc:0.795464	validation_1-auc:0.662015
# [382]	validation_0-auc:0.795508	validation_1-auc:0.662049
# [383]	validation_0-auc:0.795608	validation_1-auc:0.662036
# [384]	validation_0-auc:0.795777	validation_1-auc:0.662067
# [385]	validation_0-auc:0.796116	validation_1-auc:0.661711
# [386]	validation_0-auc:0.796175	validation_1-auc:0.661784
# [387]	validation_0-auc:0.796222	validation_1-auc:0.661831
# [388]	validation_0-auc:0.796437	validation_1-auc:0.661965
# [389]	validation_0-auc:0.796617	validation_1-auc:0.662017
# [390]	validation_0-auc:0.796926	validation_1-auc:0.661823
# [391]	validation_0-auc:0.796946	validation_1-auc:0.661814
# [392]	validation_0-auc:0.797063	validation_1-auc:0.66178
# [393]	validation_0-auc:0.79704	validation_1-auc:0.661914
# [394]	validation_0-auc:0.797086	validation_1-auc:0.661922
# [395]	validation_0-auc:0.797267	validation_1-auc:0.661784
# [396]	validation_0-auc:0.797606	validation_1-auc:0.661439
# [397]	validation_0-auc:0.797725	validation_1-auc:0.661344
# [398]	validation_0-auc:0.797902	validation_1-auc:0.66126
# [399]	validation_0-auc:0.798118	validation_1-auc:0.661422
# [400]	validation_0-auc:0.798351	validation_1-auc:0.661383
# [401]	validation_0-auc:0.798658	validation_1-auc:0.661072
# [402]	validation_0-auc:0.798734	validation_1-auc:0.661025
# [403]	validation_0-auc:0.798954	validation_1-auc:0.661154
# [404]	validation_0-auc:0.799005	validation_1-auc:0.661072
# [405]	validation_0-auc:0.799178	validation_1-auc:0.660964
# [406]	validation_0-auc:0.799463	validation_1-auc:0.660589
# [407]	validation_0-auc:0.799577	validation_1-auc:0.660563
# [408]	validation_0-auc:0.799672	validation_1-auc:0.660585
# [409]	validation_0-auc:0.799806	validation_1-auc:0.660421
# [410]	validation_0-auc:0.799864	validation_1-auc:0.660412
# [411]	validation_0-auc:0.800066	validation_1-auc:0.660572
# [412]	validation_0-auc:0.800227	validation_1-auc:0.660503
# [413]	validation_0-auc:0.800325	validation_1-auc:0.66055
# [414]	validation_0-auc:0.800425	validation_1-auc:0.660494
# [415]	validation_0-auc:0.800488	validation_1-auc:0.660468
# [416]	validation_0-auc:0.800738	validation_1-auc:0.660546
# [417]	validation_0-auc:0.800793	validation_1-auc:0.660593
# [418]	validation_0-auc:0.801151	validation_1-auc:0.660416
# [419]	validation_0-auc:0.801326	validation_1-auc:0.660606
# [420]	validation_0-auc:0.801508	validation_1-auc:0.660511
# [421]	validation_0-auc:0.801541	validation_1-auc:0.660559
# [422]	validation_0-auc:0.801657	validation_1-auc:0.660572
# [423]	validation_0-auc:0.801725	validation_1-auc:0.660636
# [424]	validation_0-auc:0.801993	validation_1-auc:0.660673
# [425]	validation_0-auc:0.802063	validation_1-auc:0.660811
# [426]	validation_0-auc:0.802434	validation_1-auc:0.660388
# [427]	validation_0-auc:0.802527	validation_1-auc:0.66041
# [428]	validation_0-auc:0.802737	validation_1-auc:0.660531
# [429]	validation_0-auc:0.802969	validation_1-auc:0.660608
# [430]	validation_0-auc:0.80326	validation_1-auc:0.660582
# [431]	validation_0-auc:0.803457	validation_1-auc:0.6606
# [432]	validation_0-auc:0.803558	validation_1-auc:0.660608
# [433]	validation_0-auc:0.803761	validation_1-auc:0.660798
# [434]	validation_0-auc:0.803928	validation_1-auc:0.660854
# [435]	validation_0-auc:0.804139	validation_1-auc:0.660753
# [436]	validation_0-auc:0.804449	validation_1-auc:0.660453
# [437]	validation_0-auc:0.804513	validation_1-auc:0.660449
# [438]	validation_0-auc:0.804663	validation_1-auc:0.660578
# [439]	validation_0-auc:0.804854	validation_1-auc:0.660652
# [440]	validation_0-auc:0.80494	validation_1-auc:0.660518
# [441]	validation_0-auc:0.805096	validation_1-auc:0.660423
# [442]	validation_0-auc:0.805167	validation_1-auc:0.660479
# [443]	validation_0-auc:0.805336	validation_1-auc:0.66041
# [444]	validation_0-auc:0.80568	validation_1-auc:0.660393
# [445]	validation_0-auc:0.80578	validation_1-auc:0.660419
# [446]	validation_0-auc:0.805847	validation_1-auc:0.660285
# [447]	validation_0-auc:0.805971	validation_1-auc:0.660341
# [448]	validation_0-auc:0.806058	validation_1-auc:0.660457
# [449]	validation_0-auc:0.806162	validation_1-auc:0.660401
# [450]	validation_0-auc:0.806316	validation_1-auc:0.660423
# [451]	validation_0-auc:0.806396	validation_1-auc:0.660505
# [452]	validation_0-auc:0.806728	validation_1-auc:0.660695
# [453]	validation_0-auc:0.80692	validation_1-auc:0.660682
# [454]	validation_0-auc:0.807065	validation_1-auc:0.66066
# [455]	validation_0-auc:0.807135	validation_1-auc:0.660733
# [456]	validation_0-auc:0.807222	validation_1-auc:0.660721
# [457]	validation_0-auc:0.807235	validation_1-auc:0.660755
# [458]	validation_0-auc:0.807451	validation_1-auc:0.660574
# [459]	validation_0-auc:0.807632	validation_1-auc:0.660639
# [460]	validation_0-auc:0.807709	validation_1-auc:0.660483
# [461]	validation_0-auc:0.807834	validation_1-auc:0.660419
# [462]	validation_0-auc:0.807949	validation_1-auc:0.660401
# [463]	validation_0-auc:0.808045	validation_1-auc:0.660414
# [464]	validation_0-auc:0.808206	validation_1-auc:0.660393
# [465]	validation_0-auc:0.808298	validation_1-auc:0.660483
# [466]	validation_0-auc:0.808417	validation_1-auc:0.660419
# [467]	validation_0-auc:0.808478	validation_1-auc:0.660328
# [468]	validation_0-auc:0.808513	validation_1-auc:0.660315
# [469]	validation_0-auc:0.8086	validation_1-auc:0.660311
# [470]	validation_0-auc:0.808611	validation_1-auc:0.66038
# [471]	validation_0-auc:0.808747	validation_1-auc:0.660483
# [472]	validation_0-auc:0.808829	validation_1-auc:0.660492
# [473]	validation_0-auc:0.808889	validation_1-auc:0.660634
# [474]	validation_0-auc:0.808965	validation_1-auc:0.660582
# [475]	validation_0-auc:0.809258	validation_1-auc:0.660462
# [476]	validation_0-auc:0.809555	validation_1-auc:0.660462
# [477]	validation_0-auc:0.809629	validation_1-auc:0.660457
# [478]	validation_0-auc:0.809919	validation_1-auc:0.660091
# [479]	validation_0-auc:0.809984	validation_1-auc:0.660078
# [480]	validation_0-auc:0.810101	validation_1-auc:0.660177
# [481]	validation_0-auc:0.810239	validation_1-auc:0.660315
# [482]	validation_0-auc:0.81066	validation_1-auc:0.660168
# [483]	validation_0-auc:0.810918	validation_1-auc:0.66003
# [484]	validation_0-auc:0.811152	validation_1-auc:0.660134
# [485]	validation_0-auc:0.811262	validation_1-auc:0.66019
# [486]	validation_0-auc:0.811379	validation_1-auc:0.660129
# [487]	validation_0-auc:0.811455	validation_1-auc:0.660138
# [488]	validation_0-auc:0.811703	validation_1-auc:0.659776
# [489]	validation_0-auc:0.811801	validation_1-auc:0.65984
# [490]	validation_0-auc:0.81189	validation_1-auc:0.659823
# [491]	validation_0-auc:0.811927	validation_1-auc:0.659862
# [492]	validation_0-auc:0.812136	validation_1-auc:0.659866
# [493]	validation_0-auc:0.81226	validation_1-auc:0.659668
# [494]	validation_0-auc:0.812382	validation_1-auc:0.659625
# [495]	validation_0-auc:0.812506	validation_1-auc:0.659521
# [496]	validation_0-auc:0.812516	validation_1-auc:0.659536
# [497]	validation_0-auc:0.812588	validation_1-auc:0.65954
# [498]	validation_0-auc:0.81275	validation_1-auc:0.659763
# [499]	validation_0-auc:0.812825	validation_1-auc:0.659728
# [500]	validation_0-auc:0.81302	validation_1-auc:0.659802
# [501]	validation_0-auc:0.813128	validation_1-auc:0.65981
# [502]	validation_0-auc:0.81322	validation_1-auc:0.659806
# [503]	validation_0-auc:0.813313	validation_1-auc:0.659733
# [504]	validation_0-auc:0.813375	validation_1-auc:0.659793
# [505]	validation_0-auc:0.8135	validation_1-auc:0.660069
# [506]	validation_0-auc:0.813561	validation_1-auc:0.660116
# [507]	validation_0-auc:0.813784	validation_1-auc:0.659858
# [508]	validation_0-auc:0.813964	validation_1-auc:0.660285
# [509]	validation_0-auc:0.814178	validation_1-auc:0.660354
# [510]	validation_0-auc:0.814243	validation_1-auc:0.660496
# [511]	validation_0-auc:0.814438	validation_1-auc:0.66047
# [512]	validation_0-auc:0.814662	validation_1-auc:0.660457
# [513]	validation_0-auc:0.814977	validation_1-auc:0.660591
# [514]	validation_0-auc:0.815189	validation_1-auc:0.660526
# [515]	validation_0-auc:0.815219	validation_1-auc:0.660488
# [516]	validation_0-auc:0.81527	validation_1-auc:0.660488
# [517]	validation_0-auc:0.815399	validation_1-auc:0.660695
# [518]	validation_0-auc:0.815524	validation_1-auc:0.660828
# [519]	validation_0-auc:0.81595	validation_1-auc:0.66041
# [520]	validation_0-auc:0.816066	validation_1-auc:0.660401
# [521]	validation_0-auc:0.816279	validation_1-auc:0.660358
# [522]	validation_0-auc:0.816562	validation_1-auc:0.660384
# [523]	validation_0-auc:0.816754	validation_1-auc:0.660069
# [524]	validation_0-auc:0.816877	validation_1-auc:0.660013
# [525]	validation_0-auc:0.816975	validation_1-auc:0.66003
# [526]	validation_0-auc:0.81703	validation_1-auc:0.660056
# [527]	validation_0-auc:0.817322	validation_1-auc:0.659745
# [528]	validation_0-auc:0.817516	validation_1-auc:0.659685
# [529]	validation_0-auc:0.817759	validation_1-auc:0.659543
# [530]	validation_0-auc:0.817817	validation_1-auc:0.659571
# [531]	validation_0-auc:0.818075	validation_1-auc:0.659482
# [532]	validation_0-auc:0.818217	validation_1-auc:0.659478
# [533]	validation_0-auc:0.818603	validation_1-auc:0.659348
# [534]	validation_0-auc:0.818656	validation_1-auc:0.659353
# [535]	validation_0-auc:0.818724	validation_1-auc:0.659443
# [536]	validation_0-auc:0.818805	validation_1-auc:0.659504
# [537]	validation_0-auc:0.819068	validation_1-auc:0.659314
# [538]	validation_0-auc:0.819258	validation_1-auc:0.659594
# [539]	validation_0-auc:0.819523	validation_1-auc:0.65951
# [540]	validation_0-auc:0.819779	validation_1-auc:0.659221
# [541]	validation_0-auc:0.819837	validation_1-auc:0.659234
# [542]	validation_0-auc:0.819976	validation_1-auc:0.65929
# [543]	validation_0-auc:0.820028	validation_1-auc:0.659286
# [544]	validation_0-auc:0.820375	validation_1-auc:0.6591
# [545]	validation_0-auc:0.820447	validation_1-auc:0.659109
# [546]	validation_0-auc:0.820534	validation_1-auc:0.659118
# [547]	validation_0-auc:0.820627	validation_1-auc:0.65926
# [548]	validation_0-auc:0.820908	validation_1-auc:0.659215
# [549]	validation_0-auc:0.821137	validation_1-auc:0.658984
# [550]	validation_0-auc:0.821308	validation_1-auc:0.658958
# [551]	validation_0-auc:0.821485	validation_1-auc:0.658993
# [552]	validation_0-auc:0.821804	validation_1-auc:0.659044
# [553]	validation_0-auc:0.822035	validation_1-auc:0.658924
# [554]	validation_0-auc:0.822188	validation_1-auc:0.658902
# [555]	validation_0-auc:0.822426	validation_1-auc:0.658863
# [556]	validation_0-auc:0.822688	validation_1-auc:0.658777
# [557]	validation_0-auc:0.822921	validation_1-auc:0.658755
# [558]	validation_0-auc:0.82303	validation_1-auc:0.658699
# [559]	validation_0-auc:0.82308	validation_1-auc:0.658721
# [560]	validation_0-auc:0.823117	validation_1-auc:0.658712
# [561]	validation_0-auc:0.823364	validation_1-auc:0.658544
# [562]	validation_0-auc:0.823427	validation_1-auc:0.658578
# [563]	validation_0-auc:0.823516	validation_1-auc:0.658634
# [564]	validation_0-auc:0.823768	validation_1-auc:0.658401
# [565]	validation_0-auc:0.823819	validation_1-auc:0.65854
# [566]	validation_0-auc:0.823909	validation_1-auc:0.658527
# [567]	validation_0-auc:0.823967	validation_1-auc:0.658621
# [568]	validation_0-auc:0.824062	validation_1-auc:0.658557
# [569]	validation_0-auc:0.824135	validation_1-auc:0.658544
# [570]	validation_0-auc:0.824225	validation_1-auc:0.658574
# [571]	validation_0-auc:0.824226	validation_1-auc:0.658682
# [572]	validation_0-auc:0.824369	validation_1-auc:0.65863
# [573]	validation_0-auc:0.824447	validation_1-auc:0.658621
# [574]	validation_0-auc:0.824534	validation_1-auc:0.658699
# [575]	validation_0-auc:0.8246	validation_1-auc:0.658682
# [576]	validation_0-auc:0.824637	validation_1-auc:0.658777
# [577]	validation_0-auc:0.824735	validation_1-auc:0.658777
# [578]	validation_0-auc:0.824959	validation_1-auc:0.658777
# [579]	validation_0-auc:0.825185	validation_1-auc:0.658617
# [580]	validation_0-auc:0.825207	validation_1-auc:0.658691
# [581]	validation_0-auc:0.825276	validation_1-auc:0.658678
# [582]	validation_0-auc:0.825344	validation_1-auc:0.658738
# [583]	validation_0-auc:0.825424	validation_1-auc:0.658854
# [584]	validation_0-auc:0.825495	validation_1-auc:0.658932
# [585]	validation_0-auc:0.825559	validation_1-auc:0.658928
# [586]	validation_0-auc:0.825668	validation_1-auc:0.658928
# [587]	validation_0-auc:0.825716	validation_1-auc:0.659049
# [588]	validation_0-auc:0.825957	validation_1-auc:0.658919
# [589]	validation_0-auc:0.826154	validation_1-auc:0.658449
# [590]	validation_0-auc:0.826371	validation_1-auc:0.658414
# [591]	validation_0-auc:0.826569	validation_1-auc:0.658242
# [592]	validation_0-auc:0.826936	validation_1-auc:0.657987
# [593]	validation_0-auc:0.827005	validation_1-auc:0.65803
# [594]	validation_0-auc:0.82723	validation_1-auc:0.658
# [595]	validation_0-auc:0.827485	validation_1-auc:0.658026
# [596]	validation_0-auc:0.827626	validation_1-auc:0.658013
# [597]	validation_0-auc:0.827737	validation_1-auc:0.657936
# [598]	validation_0-auc:0.827874	validation_1-auc:0.658065
# [599]	validation_0-auc:0.827945	validation_1-auc:0.658052
# [600]	validation_0-auc:0.827985	validation_1-auc:0.658173
# [601]	validation_0-auc:0.828302	validation_1-auc:0.657992
# [602]	validation_0-auc:0.828458	validation_1-auc:0.657996
# [603]	validation_0-auc:0.828706	validation_1-auc:0.657961
# [604]	validation_0-auc:0.828811	validation_1-auc:0.657983
# [605]	validation_0-auc:0.829082	validation_1-auc:0.657923
# [606]	validation_0-auc:0.829232	validation_1-auc:0.658078
# [607]	validation_0-auc:0.829366	validation_1-auc:0.65813
# [608]	validation_0-auc:0.829434	validation_1-auc:0.657996
# [609]	validation_0-auc:0.829568	validation_1-auc:0.65797
# [610]	validation_0-auc:0.829721	validation_1-auc:0.658048
# [611]	validation_0-auc:0.829868	validation_1-auc:0.657961
# [612]	validation_0-auc:0.829998	validation_1-auc:0.657974
# [613]	validation_0-auc:0.830229	validation_1-auc:0.657836
# [614]	validation_0-auc:0.830488	validation_1-auc:0.657651
# [615]	validation_0-auc:0.830709	validation_1-auc:0.65775
# [616]	validation_0-auc:0.830894	validation_1-auc:0.657621
# [617]	validation_0-auc:0.830954	validation_1-auc:0.657642
# [618]	validation_0-auc:0.831143	validation_1-auc:0.657608
# [619]	validation_0-auc:0.831404	validation_1-auc:0.657582
# [620]	validation_0-auc:0.83156	validation_1-auc:0.657694
# [621]	validation_0-auc:0.831594	validation_1-auc:0.657642
# [622]	validation_0-auc:0.831712	validation_1-auc:0.657534
# [623]	validation_0-auc:0.831729	validation_1-auc:0.657569
# [624]	validation_0-auc:0.831942	validation_1-auc:0.657623
# [625]	validation_0-auc:0.832134	validation_1-auc:0.657564
# Stopping. Best iteration:
# [375]	validation_0-auc:0.794533	validation_1-auc:0.662071
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.02, max_delta_step=0, max_depth=5,
#               min_child_weight=1, min_samples_split=5, missing=None,
#               n_estimators=1000, n_jobs=1, nthread=None,
#               objective='binary:logistic', random_state=31, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#               subsample=1, verbosity=1)

# %%
print("ROC score for Train is:",roc_auc_score(y_train,xgboost.predict_proba(X_train)[:,1]))
print("ROC score for Val is:",roc_auc_score(y_val,xgboost.predict_proba(X_val)[:,1]))
print("ROC score for Test is:",roc_auc_score(y_test,xgboost.predict_proba(X_test)[:,1]))
print("Accuracy score for Train is:",accuracy_score(y_train,xgboost.predict(X_train)))
print("Accuracy score for Val is:",accuracy_score(y_val,xgboost.predict(X_val)))
print("Accuracy score for Test is:",accuracy_score(y_test,xgboost.predict(X_test)))
# Out:
# ROC score for Train is: 0.7945333736922391
# ROC score for Val is: 0.6620709740049617
# ROC score for Test is: 0.6476670431835955
# Accuracy score for Train is: 0.7275082769540809
# Accuracy score for Val is: 0.67
# Accuracy score for Test is: 0.668

# %%
# ROC score for Train is: 0.7758706277752707
# ROC score for Val is: 0.659393808650631
# ROC score for Test is: 0.6535297318803133
# Accuracy score for Train is: 0.707787534187419
# Accuracy score for Val is: 0.659
# Accuracy score for Test is: 0.664

# ROC score for Train is: 0.7714897764192903
# ROC score for Val is: 0.6593743932693344
# ROC score for Test is: 0.6524001810939722
# Accuracy score for Train is: 0.7073556931049374
# Accuracy score for Val is: 0.665
# Accuracy score for Test is: 0.668

# %%
#Permutation importance with randomforest
perm_xgboost = PermutationImportance(xgboost, random_state=1,scoring='roc_auc').fit(X_val, y_val)
eli5.show_weights(perm_xgboost,feature_names=features,top=None)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0417
#
#                     &plusmn; 0.0405
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 certReason
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0225
#
#                     &plusmn; 0.0177
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 respondent
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.03%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0201
#
#                     &plusmn; 0.0038
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 issueArea
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0170
#
#                     &plusmn; 0.0053
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lcDisposition
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.06%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0154
#
#                     &plusmn; 0.0162
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 case_argued
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0148
#
#                     &plusmn; 0.0131
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 petitioner
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.98%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0075
#
#                     &plusmn; 0.0046
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 argued_since
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.20%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0071
#
#                     &plusmn; 0.0023
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 caseSourceState
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.23%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0054
#
#                     &plusmn; 0.0186
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 caseSource
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.49%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0050
#
#                     &plusmn; 0.0123
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lcDisagreement
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.50%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0035
#
#                     &plusmn; 0.0082
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 caseOriginState
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.09%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0027
#
#                     &plusmn; 0.0061
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 petitionerState
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.22%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0025
#
#                     &plusmn; 0.0055
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 respondentState
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.09%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0005
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 threeJudgeFdc
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.10%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0005
#
#                     &plusmn; 0.0059
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 caseOrigin
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 case_reargued
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 reargued_since
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.35%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0003

# %%
#Permutation importance with randomforest
perm_rfc = PermutationImportance(rfc, random_state=1,scoring='roc_auc').fit(X_val, y_val)
eli5.show_weights(perm_rfc,feature_names=features,top=None)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0266
#
#                     &plusmn; 0.0368
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 certReason
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0200
#
#                     &plusmn; 0.0125
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 respondent
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0142
#
#                     &plusmn; 0.0136
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lcDisposition
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0086
#
#                     &plusmn; 0.0015
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 issueArea
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.68%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0063
#
#                     &plusmn; 0.0130
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 case_argued
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0061
#
#                     &plusmn; 0.0112
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lcDisagreement
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0060
#
#                     &plusmn; 0.0083
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 petitioner
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0057
#
#                     &plusmn; 0.0049
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 respondentState
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.45%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0054
#
#                     &plusmn; 0.0102
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 caseOrigin
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0049
#
#                     &plusmn; 0.0045
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 caseSourceState
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0033
#
#                     &plusmn; 0.0052
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 argued_since
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0027
#
#                     &plusmn; 0.0193
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 caseSource
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.06%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0026
#
#                     &plusmn; 0.0054
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 petitionerState
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.78%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0020
#
#                     &plusmn; 0.0046
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 caseOriginState
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0006
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 threeJudgeFdc
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0005
#
#                     &plusmn; 0.0016
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 is_adminAction
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.65%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 case_reargued
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000

# %%
#Selecting features from perumation importances
feature_importances_rfc = pd.Series(dict(zip(features,perm_rfc.feature_importances_)))
feature_importances_xgb = pd.Series(dict(zip(features,perm_xgboost.feature_importances_)))
#feature_importances.sort_values().plot(kind='barh',figsize=(10,6))

# %%
selected_features_rfc = feature_importances_rfc[feature_importances_rfc >0].sort_values(ascending=False).index.tolist()
selected_features_xgb = feature_importances_xgb[feature_importances_xgb >0].sort_values(ascending=False).index.tolist()

# %%
len(selected_features_rfc),len(selected_features_xgb)
# Out:
# (18, 16)

# %%
selected_features = list((set(selected_features_rfc)|set(selected_features_xgb)))
selected_features
# Out:
# ['caseOriginState',
#  'is_adminActionState',
#  'petitionerState',
#  'certReason',
#  'petitioner',
#  'issueArea',
#  'case_reargued',
#  'caseSource',
#  'respondentState',
#  'respondent',
#  'caseSourceState',
#  'case_argued',
#  'is_adminAction',
#  'lcDisposition',
#  'argued_since',
#  'threeJudgeFdc',
#  'lcDisagreement',
#  'caseOrigin']

# %%
#Running the model with selected features
rfc.fit(train[selected_features],y_train)
print("ROC score for Train is:",roc_auc_score(y_train,rfc.predict_proba(train[selected_features])[:,1]))
print("ROC score for Val is:",roc_auc_score(y_val,rfc.predict_proba(val[selected_features])[:,1]))
print("ROC score for Test is:",roc_auc_score(y_test,rfc.predict_proba(test[selected_features])[:,1]))
print("Accuracy score for Train is:",accuracy_score(y_train,rfc.predict(train[selected_features])))
print("Accuracy score for Val is:",accuracy_score(y_val,rfc.predict(val[selected_features])))
print("Accuracy score for Test is:",accuracy_score(y_test,rfc.predict(test[selected_features])))
# Out:
# ROC score for Train is: 0.860423995574585
# ROC score for Val is: 0.6644331787293712
# ROC score for Test is: 0.6613474123226217
# Accuracy score for Train is: 0.7416150856484813
# Accuracy score for Val is: 0.668
# Accuracy score for Test is: 0.676

# %%
xgboost.fit(train[selected_features],y_train,eval_metric='auc',eval_set=[(train[selected_features],y_train),(val[selected_features],y_val)],early_stopping_rounds=100)
# Out:
# [0]	validation_0-auc:0.651243	validation_1-auc:0.602716
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 100 rounds.
# [1]	validation_0-auc:0.657696	validation_1-auc:0.620675
# [2]	validation_0-auc:0.656667	validation_1-auc:0.612806
# [3]	validation_0-auc:0.659311	validation_1-auc:0.620762
# [4]	validation_0-auc:0.659441	validation_1-auc:0.619066
# [5]	validation_0-auc:0.658986	validation_1-auc:0.621215
# [6]	validation_0-auc:0.665858	validation_1-auc:0.627475
# [7]	validation_0-auc:0.669037	validation_1-auc:0.631129
# [8]	validation_0-auc:0.670683	validation_1-auc:0.631887
# [9]	validation_0-auc:0.670188	validation_1-auc:0.632642
# [10]	validation_0-auc:0.671738	validation_1-auc:0.635565
# [11]	validation_0-auc:0.673269	validation_1-auc:0.637696
# [12]	validation_0-auc:0.672973	validation_1-auc:0.635021
# [13]	validation_0-auc:0.676017	validation_1-auc:0.637068
# [14]	validation_0-auc:0.676367	validation_1-auc:0.639776
# [15]	validation_0-auc:0.677677	validation_1-auc:0.639724
# [16]	validation_0-auc:0.677473	validation_1-auc:0.638867
# [17]	validation_0-auc:0.67946	validation_1-auc:0.640127
# [18]	validation_0-auc:0.680404	validation_1-auc:0.639034
# [19]	validation_0-auc:0.681676	validation_1-auc:0.638973
# [20]	validation_0-auc:0.682901	validation_1-auc:0.639111
# [21]	validation_0-auc:0.682921	validation_1-auc:0.638732
# [22]	validation_0-auc:0.683309	validation_1-auc:0.638546
# [23]	validation_0-auc:0.684104	validation_1-auc:0.638943
# [24]	validation_0-auc:0.684736	validation_1-auc:0.639016
# [25]	validation_0-auc:0.685279	validation_1-auc:0.639247
# [26]	validation_0-auc:0.686208	validation_1-auc:0.639079
# [27]	validation_0-auc:0.687379	validation_1-auc:0.640261
# [28]	validation_0-auc:0.687864	validation_1-auc:0.63956
# [29]	validation_0-auc:0.688146	validation_1-auc:0.638796
# [30]	validation_0-auc:0.689215	validation_1-auc:0.640425
# [31]	validation_0-auc:0.688888	validation_1-auc:0.639584
# [32]	validation_0-auc:0.688816	validation_1-auc:0.639521
# [33]	validation_0-auc:0.688515	validation_1-auc:0.64003
# [34]	validation_0-auc:0.688429	validation_1-auc:0.639499
# [35]	validation_0-auc:0.688183	validation_1-auc:0.639817
# [36]	validation_0-auc:0.688379	validation_1-auc:0.640308
# [37]	validation_0-auc:0.68852	validation_1-auc:0.641542
# [38]	validation_0-auc:0.689085	validation_1-auc:0.64211
# [39]	validation_0-auc:0.689401	validation_1-auc:0.64242
# [40]	validation_0-auc:0.689249	validation_1-auc:0.641929
# [41]	validation_0-auc:0.689432	validation_1-auc:0.642511
# [42]	validation_0-auc:0.689366	validation_1-auc:0.642886
# [43]	validation_0-auc:0.689333	validation_1-auc:0.643818
# [44]	validation_0-auc:0.68933	validation_1-auc:0.644276
# [45]	validation_0-auc:0.689989	validation_1-auc:0.644349
# [46]	validation_0-auc:0.69051	validation_1-auc:0.644554
# [47]	validation_0-auc:0.690815	validation_1-auc:0.64444
# [48]	validation_0-auc:0.691211	validation_1-auc:0.645134
# [49]	validation_0-auc:0.692274	validation_1-auc:0.645177
# [50]	validation_0-auc:0.692486	validation_1-auc:0.645123
# [51]	validation_0-auc:0.692951	validation_1-auc:0.645201
# [52]	validation_0-auc:0.693966	validation_1-auc:0.644159
# [53]	validation_0-auc:0.695034	validation_1-auc:0.643853
# [54]	validation_0-auc:0.696026	validation_1-auc:0.644276
# [55]	validation_0-auc:0.696424	validation_1-auc:0.643693
# [56]	validation_0-auc:0.697702	validation_1-auc:0.643324
# [57]	validation_0-auc:0.698213	validation_1-auc:0.642621
# [58]	validation_0-auc:0.699922	validation_1-auc:0.643443
# [59]	validation_0-auc:0.700381	validation_1-auc:0.643055
# [60]	validation_0-auc:0.70196	validation_1-auc:0.643085
# [61]	validation_0-auc:0.702334	validation_1-auc:0.64302
# [62]	validation_0-auc:0.703852	validation_1-auc:0.64294
# [63]	validation_0-auc:0.704022	validation_1-auc:0.643089
# [64]	validation_0-auc:0.70449	validation_1-auc:0.643191
# [65]	validation_0-auc:0.704849	validation_1-auc:0.642994
# [66]	validation_0-auc:0.70592	validation_1-auc:0.642776
# [67]	validation_0-auc:0.706292	validation_1-auc:0.643109
# [68]	validation_0-auc:0.707609	validation_1-auc:0.642789
# [69]	validation_0-auc:0.708219	validation_1-auc:0.643053
# [70]	validation_0-auc:0.708413	validation_1-auc:0.643223
# [71]	validation_0-auc:0.708844	validation_1-auc:0.642949
# [72]	validation_0-auc:0.70984	validation_1-auc:0.643607
# [73]	validation_0-auc:0.710145	validation_1-auc:0.643883
# [74]	validation_0-auc:0.710953	validation_1-auc:0.64381
# [75]	validation_0-auc:0.711719	validation_1-auc:0.643967
# [76]	validation_0-auc:0.712909	validation_1-auc:0.644289
# [77]	validation_0-auc:0.713129	validation_1-auc:0.644487
# [78]	validation_0-auc:0.714172	validation_1-auc:0.644921
# [79]	validation_0-auc:0.714902	validation_1-auc:0.645658
# [80]	validation_0-auc:0.715136	validation_1-auc:0.645887
# [81]	validation_0-auc:0.715872	validation_1-auc:0.645555
# [82]	validation_0-auc:0.715969	validation_1-auc:0.645482
# [83]	validation_0-auc:0.716601	validation_1-auc:0.645542
# [84]	validation_0-auc:0.717158	validation_1-auc:0.64606
# [85]	validation_0-auc:0.717852	validation_1-auc:0.64653
# [86]	validation_0-auc:0.718764	validation_1-auc:0.646668
# [87]	validation_0-auc:0.718985	validation_1-auc:0.646698
# [88]	validation_0-auc:0.719929	validation_1-auc:0.646823
# [89]	validation_0-auc:0.720346	validation_1-auc:0.646892
# [90]	validation_0-auc:0.721034	validation_1-auc:0.646718
# [91]	validation_0-auc:0.721463	validation_1-auc:0.646636
# [92]	validation_0-auc:0.722162	validation_1-auc:0.647436
# [93]	validation_0-auc:0.72302	validation_1-auc:0.647525
# [94]	validation_0-auc:0.72381	validation_1-auc:0.647509
# [95]	validation_0-auc:0.724027	validation_1-auc:0.647432
# [96]	validation_0-auc:0.724343	validation_1-auc:0.647296
# [97]	validation_0-auc:0.725329	validation_1-auc:0.647747
# [98]	validation_0-auc:0.72543	validation_1-auc:0.647606
# [99]	validation_0-auc:0.72614	validation_1-auc:0.647727
# [100]	validation_0-auc:0.726747	validation_1-auc:0.647788
# [101]	validation_0-auc:0.727314	validation_1-auc:0.647952
# [102]	validation_0-auc:0.727237	validation_1-auc:0.648042
# [103]	validation_0-auc:0.728041	validation_1-auc:0.648541
# [104]	validation_0-auc:0.728571	validation_1-auc:0.648586
# [105]	validation_0-auc:0.72876	validation_1-auc:0.648461
# [106]	validation_0-auc:0.729504	validation_1-auc:0.649259
# [107]	validation_0-auc:0.730005	validation_1-auc:0.649306
# [108]	validation_0-auc:0.73042	validation_1-auc:0.649265
# [109]	validation_0-auc:0.730623	validation_1-auc:0.649419
# [110]	validation_0-auc:0.730714	validation_1-auc:0.649125
# [111]	validation_0-auc:0.731479	validation_1-auc:0.649703
# [112]	validation_0-auc:0.731896	validation_1-auc:0.649878
# [113]	validation_0-auc:0.732273	validation_1-auc:0.649831
# [114]	validation_0-auc:0.732401	validation_1-auc:0.650105
# [115]	validation_0-auc:0.732891	validation_1-auc:0.649964
# [116]	validation_0-auc:0.733609	validation_1-auc:0.650551
# [117]	validation_0-auc:0.734038	validation_1-auc:0.650948
# [118]	validation_0-auc:0.734148	validation_1-auc:0.651047
# [119]	validation_0-auc:0.734611	validation_1-auc:0.651125
# [120]	validation_0-auc:0.7353	validation_1-auc:0.65172
# [121]	validation_0-auc:0.735683	validation_1-auc:0.651966
# [122]	validation_0-auc:0.736176	validation_1-auc:0.651923
# [123]	validation_0-auc:0.73637	validation_1-auc:0.651992
# [124]	validation_0-auc:0.736623	validation_1-auc:0.651822
# [125]	validation_0-auc:0.736759	validation_1-auc:0.651921
# [126]	validation_0-auc:0.738011	validation_1-auc:0.651604
# [127]	validation_0-auc:0.738676	validation_1-auc:0.651565
# [128]	validation_0-auc:0.738799	validation_1-auc:0.651695
# [129]	validation_0-auc:0.739314	validation_1-auc:0.651397
# [130]	validation_0-auc:0.739607	validation_1-auc:0.651682
# [131]	validation_0-auc:0.740336	validation_1-auc:0.65194
# [132]	validation_0-auc:0.74051	validation_1-auc:0.651884
# [133]	validation_0-auc:0.740581	validation_1-auc:0.651915
# [134]	validation_0-auc:0.741164	validation_1-auc:0.651772
# [135]	validation_0-auc:0.742188	validation_1-auc:0.652122
# [136]	validation_0-auc:0.742426	validation_1-auc:0.652122
# [137]	validation_0-auc:0.742772	validation_1-auc:0.652079
# [138]	validation_0-auc:0.743628	validation_1-auc:0.652393
# [139]	validation_0-auc:0.743674	validation_1-auc:0.652286
# [140]	validation_0-auc:0.744586	validation_1-auc:0.652368
# [141]	validation_0-auc:0.745311	validation_1-auc:0.652857
# [142]	validation_0-auc:0.745704	validation_1-auc:0.653161
# [143]	validation_0-auc:0.745754	validation_1-auc:0.6533
# [144]	validation_0-auc:0.746599	validation_1-auc:0.653817
# [145]	validation_0-auc:0.746802	validation_1-auc:0.653964
# [146]	validation_0-auc:0.747554	validation_1-auc:0.654016
# [147]	validation_0-auc:0.748358	validation_1-auc:0.653904
# [148]	validation_0-auc:0.748354	validation_1-auc:0.654061
# [149]	validation_0-auc:0.748563	validation_1-auc:0.65416
# [150]	validation_0-auc:0.749171	validation_1-auc:0.654333
# [151]	validation_0-auc:0.749418	validation_1-auc:0.653845
# [152]	validation_0-auc:0.749565	validation_1-auc:0.653996
# [153]	validation_0-auc:0.749782	validation_1-auc:0.653828
# [154]	validation_0-auc:0.750515	validation_1-auc:0.653733
# [155]	validation_0-auc:0.750703	validation_1-auc:0.653647
# [156]	validation_0-auc:0.751056	validation_1-auc:0.653858
# [157]	validation_0-auc:0.751078	validation_1-auc:0.653888
# [158]	validation_0-auc:0.751762	validation_1-auc:0.654042
# [159]	validation_0-auc:0.752057	validation_1-auc:0.653839
# [160]	validation_0-auc:0.752735	validation_1-auc:0.653545
# [161]	validation_0-auc:0.752725	validation_1-auc:0.653645
# [162]	validation_0-auc:0.752925	validation_1-auc:0.653813
# [163]	validation_0-auc:0.753154	validation_1-auc:0.653955
# [164]	validation_0-auc:0.753537	validation_1-auc:0.653847
# [165]	validation_0-auc:0.753683	validation_1-auc:0.653921
# [166]	validation_0-auc:0.753929	validation_1-auc:0.653977
# [167]	validation_0-auc:0.754634	validation_1-auc:0.653895
# [168]	validation_0-auc:0.75529	validation_1-auc:0.653904
# [169]	validation_0-auc:0.755597	validation_1-auc:0.653433
# [170]	validation_0-auc:0.755572	validation_1-auc:0.653399
# [171]	validation_0-auc:0.756014	validation_1-auc:0.653291
# [172]	validation_0-auc:0.75614	validation_1-auc:0.653183
# [173]	validation_0-auc:0.756658	validation_1-auc:0.653149
# [174]	validation_0-auc:0.75685	validation_1-auc:0.653261
# [175]	validation_0-auc:0.757387	validation_1-auc:0.653218
# [176]	validation_0-auc:0.75763	validation_1-auc:0.653416
# [177]	validation_0-auc:0.758175	validation_1-auc:0.653353
# [178]	validation_0-auc:0.758563	validation_1-auc:0.653198
# [179]	validation_0-auc:0.75861	validation_1-auc:0.652952
# [180]	validation_0-auc:0.75877	validation_1-auc:0.652851
# [181]	validation_0-auc:0.759127	validation_1-auc:0.653308
# [182]	validation_0-auc:0.759378	validation_1-auc:0.653485
# [183]	validation_0-auc:0.759721	validation_1-auc:0.653373
# [184]	validation_0-auc:0.759994	validation_1-auc:0.653632
# [185]	validation_0-auc:0.760147	validation_1-auc:0.65374
# [186]	validation_0-auc:0.760418	validation_1-auc:0.65352
# [187]	validation_0-auc:0.760431	validation_1-auc:0.653554
# [188]	validation_0-auc:0.760898	validation_1-auc:0.653619
# [189]	validation_0-auc:0.761072	validation_1-auc:0.653578
# [190]	validation_0-auc:0.761511	validation_1-auc:0.65358
# [191]	validation_0-auc:0.761846	validation_1-auc:0.653986
# [192]	validation_0-auc:0.761989	validation_1-auc:0.653925
# [193]	validation_0-auc:0.762331	validation_1-auc:0.654193
# [194]	validation_0-auc:0.762358	validation_1-auc:0.654262
# [195]	validation_0-auc:0.762745	validation_1-auc:0.654145
# [196]	validation_0-auc:0.76284	validation_1-auc:0.654313
# [197]	validation_0-auc:0.763036	validation_1-auc:0.654641
# [198]	validation_0-auc:0.763191	validation_1-auc:0.654464
# [199]	validation_0-auc:0.763565	validation_1-auc:0.654659
# [200]	validation_0-auc:0.763575	validation_1-auc:0.654663
# [201]	validation_0-auc:0.763763	validation_1-auc:0.65484
# [202]	validation_0-auc:0.763985	validation_1-auc:0.654775
# [203]	validation_0-auc:0.764085	validation_1-auc:0.65484
# [204]	validation_0-auc:0.764217	validation_1-auc:0.654805
# [205]	validation_0-auc:0.764438	validation_1-auc:0.654788
# [206]	validation_0-auc:0.764709	validation_1-auc:0.655097
# [207]	validation_0-auc:0.764723	validation_1-auc:0.655073
# [208]	validation_0-auc:0.764824	validation_1-auc:0.654831
# [209]	validation_0-auc:0.765067	validation_1-auc:0.65481
# [210]	validation_0-auc:0.765219	validation_1-auc:0.6549
# [211]	validation_0-auc:0.765611	validation_1-auc:0.654775
# [212]	validation_0-auc:0.765618	validation_1-auc:0.654883
# [213]	validation_0-auc:0.765851	validation_1-auc:0.654922
# [214]	validation_0-auc:0.765973	validation_1-auc:0.654883
# [215]	validation_0-auc:0.766177	validation_1-auc:0.654943
# [216]	validation_0-auc:0.76633	validation_1-auc:0.655015
# [217]	validation_0-auc:0.766543	validation_1-auc:0.654967
# [218]	validation_0-auc:0.766642	validation_1-auc:0.655045
# [219]	validation_0-auc:0.767067	validation_1-auc:0.655101
# [220]	validation_0-auc:0.767249	validation_1-auc:0.654864
# [221]	validation_0-auc:0.767576	validation_1-auc:0.654816
# [222]	validation_0-auc:0.767704	validation_1-auc:0.654885
# [223]	validation_0-auc:0.767731	validation_1-auc:0.654872
# [224]	validation_0-auc:0.767916	validation_1-auc:0.654915
# [225]	validation_0-auc:0.767995	validation_1-auc:0.654963
# [226]	validation_0-auc:0.768117	validation_1-auc:0.655036
# [227]	validation_0-auc:0.768233	validation_1-auc:0.655105
# [228]	validation_0-auc:0.768555	validation_1-auc:0.654995
# [229]	validation_0-auc:0.768554	validation_1-auc:0.654978
# [230]	validation_0-auc:0.768918	validation_1-auc:0.655034
# [231]	validation_0-auc:0.768998	validation_1-auc:0.655194
# [232]	validation_0-auc:0.769495	validation_1-auc:0.655332
# [233]	validation_0-auc:0.76977	validation_1-auc:0.655319
# [234]	validation_0-auc:0.7699	validation_1-auc:0.655401
# [235]	validation_0-auc:0.769983	validation_1-auc:0.655552
# [236]	validation_0-auc:0.770216	validation_1-auc:0.655457
# [237]	validation_0-auc:0.770608	validation_1-auc:0.655263
# [238]	validation_0-auc:0.770704	validation_1-auc:0.6552
# [239]	validation_0-auc:0.77086	validation_1-auc:0.655342
# [240]	validation_0-auc:0.77119	validation_1-auc:0.655373
# [241]	validation_0-auc:0.771325	validation_1-auc:0.655321
# [242]	validation_0-auc:0.771335	validation_1-auc:0.655291
# [243]	validation_0-auc:0.771572	validation_1-auc:0.655239
# [244]	validation_0-auc:0.771902	validation_1-auc:0.655066
# [245]	validation_0-auc:0.772	validation_1-auc:0.655161
# [246]	validation_0-auc:0.772125	validation_1-auc:0.655355
# [247]	validation_0-auc:0.772409	validation_1-auc:0.655368
# [248]	validation_0-auc:0.772679	validation_1-auc:0.655265
# [249]	validation_0-auc:0.772762	validation_1-auc:0.655248
# [250]	validation_0-auc:0.773086	validation_1-auc:0.654993
# [251]	validation_0-auc:0.773342	validation_1-auc:0.655032
# [252]	validation_0-auc:0.773551	validation_1-auc:0.654967
# [253]	validation_0-auc:0.773699	validation_1-auc:0.654984
# [254]	validation_0-auc:0.773992	validation_1-auc:0.654812
# [255]	validation_0-auc:0.774117	validation_1-auc:0.654954
# [256]	validation_0-auc:0.774192	validation_1-auc:0.655114
# [257]	validation_0-auc:0.774273	validation_1-auc:0.655226
# [258]	validation_0-auc:0.774413	validation_1-auc:0.655097
# [259]	validation_0-auc:0.774563	validation_1-auc:0.655075
# [260]	validation_0-auc:0.774614	validation_1-auc:0.655217
# [261]	validation_0-auc:0.774912	validation_1-auc:0.655088
# [262]	validation_0-auc:0.775047	validation_1-auc:0.655075
# [263]	validation_0-auc:0.775291	validation_1-auc:0.654971
# [264]	validation_0-auc:0.775474	validation_1-auc:0.655127
# [265]	validation_0-auc:0.775629	validation_1-auc:0.655148
# [266]	validation_0-auc:0.775781	validation_1-auc:0.655174
# [267]	validation_0-auc:0.776012	validation_1-auc:0.655094
# [268]	validation_0-auc:0.776113	validation_1-auc:0.655038
# [269]	validation_0-auc:0.776363	validation_1-auc:0.655086
# [270]	validation_0-auc:0.776719	validation_1-auc:0.655319
# [271]	validation_0-auc:0.777028	validation_1-auc:0.655487
# [272]	validation_0-auc:0.777087	validation_1-auc:0.655392
# [273]	validation_0-auc:0.777381	validation_1-auc:0.655332
# [274]	validation_0-auc:0.777685	validation_1-auc:0.655366
# [275]	validation_0-auc:0.77779	validation_1-auc:0.655526
# [276]	validation_0-auc:0.777919	validation_1-auc:0.655711
# [277]	validation_0-auc:0.777996	validation_1-auc:0.655599
# [278]	validation_0-auc:0.778115	validation_1-auc:0.655703
# [279]	validation_0-auc:0.778182	validation_1-auc:0.655832
# [280]	validation_0-auc:0.778459	validation_1-auc:0.656268
# [281]	validation_0-auc:0.77859	validation_1-auc:0.656445
# [282]	validation_0-auc:0.77871	validation_1-auc:0.656574
# [283]	validation_0-auc:0.778765	validation_1-auc:0.656656
# [284]	validation_0-auc:0.779006	validation_1-auc:0.656855
# [285]	validation_0-auc:0.77915	validation_1-auc:0.656717
# [286]	validation_0-auc:0.779298	validation_1-auc:0.656976
# [287]	validation_0-auc:0.779388	validation_1-auc:0.65685
# [288]	validation_0-auc:0.779545	validation_1-auc:0.656842
# [289]	validation_0-auc:0.77963	validation_1-auc:0.656855
# [290]	validation_0-auc:0.779926	validation_1-auc:0.657161
# [291]	validation_0-auc:0.780227	validation_1-auc:0.657278
# [292]	validation_0-auc:0.780296	validation_1-auc:0.657321
# [293]	validation_0-auc:0.780592	validation_1-auc:0.657485
# [294]	validation_0-auc:0.780703	validation_1-auc:0.657653
# [295]	validation_0-auc:0.780995	validation_1-auc:0.657597
# [296]	validation_0-auc:0.781234	validation_1-auc:0.657394
# [297]	validation_0-auc:0.781537	validation_1-auc:0.657562
# [298]	validation_0-auc:0.781786	validation_1-auc:0.657687
# [299]	validation_0-auc:0.782059	validation_1-auc:0.657942
# [300]	validation_0-auc:0.782135	validation_1-auc:0.658115
# [301]	validation_0-auc:0.782429	validation_1-auc:0.657912
# [302]	validation_0-auc:0.782453	validation_1-auc:0.657877
# [303]	validation_0-auc:0.78275	validation_1-auc:0.658097
# [304]	validation_0-auc:0.782943	validation_1-auc:0.657955
# [305]	validation_0-auc:0.783004	validation_1-auc:0.657998
# [306]	validation_0-auc:0.783105	validation_1-auc:0.658084
# [307]	validation_0-auc:0.783154	validation_1-auc:0.658227
# [308]	validation_0-auc:0.783472	validation_1-auc:0.658641
# [309]	validation_0-auc:0.783677	validation_1-auc:0.658628
# [310]	validation_0-auc:0.783819	validation_1-auc:0.658805
# [311]	validation_0-auc:0.784151	validation_1-auc:0.658917
# [312]	validation_0-auc:0.784352	validation_1-auc:0.659189
# [313]	validation_0-auc:0.784594	validation_1-auc:0.659368
# [314]	validation_0-auc:0.784679	validation_1-auc:0.659251
# [315]	validation_0-auc:0.784881	validation_1-auc:0.659247
# [316]	validation_0-auc:0.785078	validation_1-auc:0.659346
# [317]	validation_0-auc:0.785313	validation_1-auc:0.659282
# [318]	validation_0-auc:0.785386	validation_1-auc:0.659174
# [319]	validation_0-auc:0.785555	validation_1-auc:0.65926
# [320]	validation_0-auc:0.785547	validation_1-auc:0.65923
# [321]	validation_0-auc:0.78583	validation_1-auc:0.659424
# [322]	validation_0-auc:0.785995	validation_1-auc:0.659394
# [323]	validation_0-auc:0.78625	validation_1-auc:0.659653
# [324]	validation_0-auc:0.786306	validation_1-auc:0.659618
# [325]	validation_0-auc:0.786585	validation_1-auc:0.659409
# [326]	validation_0-auc:0.786647	validation_1-auc:0.659405
# [327]	validation_0-auc:0.786933	validation_1-auc:0.659301
# [328]	validation_0-auc:0.787458	validation_1-auc:0.659262
# [329]	validation_0-auc:0.787804	validation_1-auc:0.659431
# [330]	validation_0-auc:0.787986	validation_1-auc:0.659448
# [331]	validation_0-auc:0.788459	validation_1-auc:0.659426
# [332]	validation_0-auc:0.788591	validation_1-auc:0.659594
# [333]	validation_0-auc:0.788856	validation_1-auc:0.659657
# [334]	validation_0-auc:0.789141	validation_1-auc:0.659942
# [335]	validation_0-auc:0.789295	validation_1-auc:0.659903
# [336]	validation_0-auc:0.789515	validation_1-auc:0.660052
# [337]	validation_0-auc:0.789753	validation_1-auc:0.660099
# [338]	validation_0-auc:0.790004	validation_1-auc:0.66003
# [339]	validation_0-auc:0.790168	validation_1-auc:0.660091
# [340]	validation_0-auc:0.790215	validation_1-auc:0.660073
# [341]	validation_0-auc:0.790484	validation_1-auc:0.659978
# [342]	validation_0-auc:0.790707	validation_1-auc:0.66003
# [343]	validation_0-auc:0.790891	validation_1-auc:0.660078
# [344]	validation_0-auc:0.791074	validation_1-auc:0.660263
# [345]	validation_0-auc:0.791428	validation_1-auc:0.660194
# [346]	validation_0-auc:0.791695	validation_1-auc:0.66006
# [347]	validation_0-auc:0.791952	validation_1-auc:0.66038
# [348]	validation_0-auc:0.792091	validation_1-auc:0.660457
# [349]	validation_0-auc:0.79237	validation_1-auc:0.660259
# [350]	validation_0-auc:0.792512	validation_1-auc:0.660345
# [351]	validation_0-auc:0.792645	validation_1-auc:0.660354
# [352]	validation_0-auc:0.792771	validation_1-auc:0.660242
# [353]	validation_0-auc:0.793199	validation_1-auc:0.660337
# [354]	validation_0-auc:0.79337	validation_1-auc:0.660324
# [355]	validation_0-auc:0.793585	validation_1-auc:0.660574
# [356]	validation_0-auc:0.793708	validation_1-auc:0.66066
# [357]	validation_0-auc:0.793904	validation_1-auc:0.660535
# [358]	validation_0-auc:0.794224	validation_1-auc:0.660785
# [359]	validation_0-auc:0.794391	validation_1-auc:0.66063
# [360]	validation_0-auc:0.794579	validation_1-auc:0.660578
# [361]	validation_0-auc:0.794682	validation_1-auc:0.660613
# [362]	validation_0-auc:0.794807	validation_1-auc:0.660548
# [363]	validation_0-auc:0.79491	validation_1-auc:0.660526
# [364]	validation_0-auc:0.795148	validation_1-auc:0.660841
# [365]	validation_0-auc:0.79517	validation_1-auc:0.660837
# [366]	validation_0-auc:0.795277	validation_1-auc:0.660872
# [367]	validation_0-auc:0.795529	validation_1-auc:0.660964
# [368]	validation_0-auc:0.795605	validation_1-auc:0.660943
# [369]	validation_0-auc:0.795735	validation_1-auc:0.661163
# [370]	validation_0-auc:0.795811	validation_1-auc:0.661154
# [371]	validation_0-auc:0.795913	validation_1-auc:0.66118
# [372]	validation_0-auc:0.796078	validation_1-auc:0.661279
# [373]	validation_0-auc:0.796151	validation_1-auc:0.661279
# [374]	validation_0-auc:0.796333	validation_1-auc:0.661206
# [375]	validation_0-auc:0.796588	validation_1-auc:0.661184
# [376]	validation_0-auc:0.79669	validation_1-auc:0.661163
# [377]	validation_0-auc:0.796924	validation_1-auc:0.661163
# [378]	validation_0-auc:0.796975	validation_1-auc:0.661193
# [379]	validation_0-auc:0.797046	validation_1-auc:0.661072
# [380]	validation_0-auc:0.797263	validation_1-auc:0.661266
# [381]	validation_0-auc:0.797844	validation_1-auc:0.661167
# [382]	validation_0-auc:0.797939	validation_1-auc:0.66121
# [383]	validation_0-auc:0.798339	validation_1-auc:0.661599
# [384]	validation_0-auc:0.798436	validation_1-auc:0.661586
# [385]	validation_0-auc:0.798496	validation_1-auc:0.661603
# [386]	validation_0-auc:0.798677	validation_1-auc:0.661607
# [387]	validation_0-auc:0.798776	validation_1-auc:0.66162
# [388]	validation_0-auc:0.79895	validation_1-auc:0.661737
# [389]	validation_0-auc:0.799443	validation_1-auc:0.661603
# [390]	validation_0-auc:0.799773	validation_1-auc:0.661473
# [391]	validation_0-auc:0.800095	validation_1-auc:0.661577
# [392]	validation_0-auc:0.800098	validation_1-auc:0.66159
# [393]	validation_0-auc:0.800145	validation_1-auc:0.661611
# [394]	validation_0-auc:0.800255	validation_1-auc:0.66156
# [395]	validation_0-auc:0.800515	validation_1-auc:0.661525
# [396]	validation_0-auc:0.800563	validation_1-auc:0.66156
# [397]	validation_0-auc:0.800715	validation_1-auc:0.661659
# [398]	validation_0-auc:0.800766	validation_1-auc:0.661642
# [399]	validation_0-auc:0.800906	validation_1-auc:0.661728
# [400]	validation_0-auc:0.800993	validation_1-auc:0.661758
# [401]	validation_0-auc:0.801165	validation_1-auc:0.661676
# [402]	validation_0-auc:0.801431	validation_1-auc:0.661758
# [403]	validation_0-auc:0.80149	validation_1-auc:0.661685
# [404]	validation_0-auc:0.801755	validation_1-auc:0.661534
# [405]	validation_0-auc:0.802067	validation_1-auc:0.661706
# [406]	validation_0-auc:0.802367	validation_1-auc:0.661659
# [407]	validation_0-auc:0.802483	validation_1-auc:0.661637
# [408]	validation_0-auc:0.802572	validation_1-auc:0.66181
# [409]	validation_0-auc:0.802715	validation_1-auc:0.661806
# [410]	validation_0-auc:0.802802	validation_1-auc:0.661797
# [411]	validation_0-auc:0.802865	validation_1-auc:0.661827
# [412]	validation_0-auc:0.802983	validation_1-auc:0.661814
# [413]	validation_0-auc:0.803262	validation_1-auc:0.661672
# [414]	validation_0-auc:0.803348	validation_1-auc:0.661793
# [415]	validation_0-auc:0.803646	validation_1-auc:0.661914
# [416]	validation_0-auc:0.803917	validation_1-auc:0.661888
# [417]	validation_0-auc:0.80417	validation_1-auc:0.661681
# [418]	validation_0-auc:0.804412	validation_1-auc:0.661439
# [419]	validation_0-auc:0.80452	validation_1-auc:0.661495
# [420]	validation_0-auc:0.804988	validation_1-auc:0.661275
# [421]	validation_0-auc:0.805234	validation_1-auc:0.661301
# [422]	validation_0-auc:0.805311	validation_1-auc:0.661322
# [423]	validation_0-auc:0.805446	validation_1-auc:0.661452
# [424]	validation_0-auc:0.805528	validation_1-auc:0.661435
# [425]	validation_0-auc:0.805631	validation_1-auc:0.661478
# [426]	validation_0-auc:0.80569	validation_1-auc:0.661495
# [427]	validation_0-auc:0.805752	validation_1-auc:0.66156
# [428]	validation_0-auc:0.806035	validation_1-auc:0.661603
# [429]	validation_0-auc:0.806105	validation_1-auc:0.661603
# [430]	validation_0-auc:0.806187	validation_1-auc:0.661685
# [431]	validation_0-auc:0.806496	validation_1-auc:0.661719
# [432]	validation_0-auc:0.80674	validation_1-auc:0.661439
# [433]	validation_0-auc:0.806972	validation_1-auc:0.661236
# [434]	validation_0-auc:0.807111	validation_1-auc:0.661396
# [435]	validation_0-auc:0.80744	validation_1-auc:0.66121
# [436]	validation_0-auc:0.807523	validation_1-auc:0.661258
# [437]	validation_0-auc:0.807589	validation_1-auc:0.661253
# [438]	validation_0-auc:0.807757	validation_1-auc:0.66124
# [439]	validation_0-auc:0.807815	validation_1-auc:0.661249
# [440]	validation_0-auc:0.808038	validation_1-auc:0.661348
# [441]	validation_0-auc:0.808323	validation_1-auc:0.661542
# [442]	validation_0-auc:0.808533	validation_1-auc:0.661551
# [443]	validation_0-auc:0.808691	validation_1-auc:0.661728
# [444]	validation_0-auc:0.808948	validation_1-auc:0.661844
# [445]	validation_0-auc:0.809194	validation_1-auc:0.661922
# [446]	validation_0-auc:0.809346	validation_1-auc:0.661965
# [447]	validation_0-auc:0.809407	validation_1-auc:0.662039
# [448]	validation_0-auc:0.80956	validation_1-auc:0.66165
# [449]	validation_0-auc:0.809657	validation_1-auc:0.661607
# [450]	validation_0-auc:0.809912	validation_1-auc:0.661706
# [451]	validation_0-auc:0.809974	validation_1-auc:0.661732
# [452]	validation_0-auc:0.810128	validation_1-auc:0.661788
# [453]	validation_0-auc:0.810409	validation_1-auc:0.66181
# [454]	validation_0-auc:0.810463	validation_1-auc:0.661844
# [455]	validation_0-auc:0.810673	validation_1-auc:0.661642
# [456]	validation_0-auc:0.81092	validation_1-auc:0.661831
# [457]	validation_0-auc:0.811139	validation_1-auc:0.661797
# [458]	validation_0-auc:0.811375	validation_1-auc:0.661909
# [459]	validation_0-auc:0.811507	validation_1-auc:0.661866
# [460]	validation_0-auc:0.811644	validation_1-auc:0.662069
# [461]	validation_0-auc:0.811692	validation_1-auc:0.66206
# [462]	validation_0-auc:0.811918	validation_1-auc:0.662021
# [463]	validation_0-auc:0.812063	validation_1-auc:0.662099
# [464]	validation_0-auc:0.812215	validation_1-auc:0.662423
# [465]	validation_0-auc:0.812404	validation_1-auc:0.662479
# [466]	validation_0-auc:0.812574	validation_1-auc:0.662379
# [467]	validation_0-auc:0.812801	validation_1-auc:0.662367
# [468]	validation_0-auc:0.812924	validation_1-auc:0.66252
# [469]	validation_0-auc:0.812958	validation_1-auc:0.662589
# [470]	validation_0-auc:0.81321	validation_1-auc:0.662634
# [471]	validation_0-auc:0.813326	validation_1-auc:0.662828
# [472]	validation_0-auc:0.813471	validation_1-auc:0.66288
# [473]	validation_0-auc:0.81366	validation_1-auc:0.662876
# [474]	validation_0-auc:0.813814	validation_1-auc:0.662958
# [475]	validation_0-auc:0.814042	validation_1-auc:0.66282
# [476]	validation_0-auc:0.814166	validation_1-auc:0.662945
# [477]	validation_0-auc:0.81423	validation_1-auc:0.663048
# [478]	validation_0-auc:0.814278	validation_1-auc:0.663057
# [479]	validation_0-auc:0.814455	validation_1-auc:0.66291
# [480]	validation_0-auc:0.814648	validation_1-auc:0.662889
# [481]	validation_0-auc:0.814673	validation_1-auc:0.662897
# [482]	validation_0-auc:0.814728	validation_1-auc:0.662889
# [483]	validation_0-auc:0.814786	validation_1-auc:0.66288
# [484]	validation_0-auc:0.814909	validation_1-auc:0.662962
# [485]	validation_0-auc:0.815063	validation_1-auc:0.662781
# [486]	validation_0-auc:0.815104	validation_1-auc:0.662807
# [487]	validation_0-auc:0.815225	validation_1-auc:0.662729
# [488]	validation_0-auc:0.815278	validation_1-auc:0.662733
# [489]	validation_0-auc:0.815525	validation_1-auc:0.662677
# [490]	validation_0-auc:0.81555	validation_1-auc:0.66269
# [491]	validation_0-auc:0.815584	validation_1-auc:0.662699
# [492]	validation_0-auc:0.815645	validation_1-auc:0.662612
# [493]	validation_0-auc:0.816014	validation_1-auc:0.662155
# [494]	validation_0-auc:0.816234	validation_1-auc:0.661995
# [495]	validation_0-auc:0.816312	validation_1-auc:0.662004
# [496]	validation_0-auc:0.816439	validation_1-auc:0.662052
# [497]	validation_0-auc:0.816603	validation_1-auc:0.661907
# [498]	validation_0-auc:0.816758	validation_1-auc:0.661991
# [499]	validation_0-auc:0.816794	validation_1-auc:0.661983
# [500]	validation_0-auc:0.816995	validation_1-auc:0.661689
# [501]	validation_0-auc:0.817036	validation_1-auc:0.661709
# [502]	validation_0-auc:0.817072	validation_1-auc:0.661678
# [503]	validation_0-auc:0.817172	validation_1-auc:0.661646
# [504]	validation_0-auc:0.817217	validation_1-auc:0.661644
# [505]	validation_0-auc:0.817402	validation_1-auc:0.661575
# [506]	validation_0-auc:0.817689	validation_1-auc:0.661154
# [507]	validation_0-auc:0.817761	validation_1-auc:0.661124
# [508]	validation_0-auc:0.817812	validation_1-auc:0.661296
# [509]	validation_0-auc:0.818025	validation_1-auc:0.661029
# [510]	validation_0-auc:0.818066	validation_1-auc:0.661068
# [511]	validation_0-auc:0.818137	validation_1-auc:0.661029
# [512]	validation_0-auc:0.81825	validation_1-auc:0.66099
# [513]	validation_0-auc:0.818419	validation_1-auc:0.661189
# [514]	validation_0-auc:0.818593	validation_1-auc:0.6609
# [515]	validation_0-auc:0.818698	validation_1-auc:0.660843
# [516]	validation_0-auc:0.818866	validation_1-auc:0.660723
# [517]	validation_0-auc:0.818989	validation_1-auc:0.660649
# [518]	validation_0-auc:0.819202	validation_1-auc:0.660731
# [519]	validation_0-auc:0.819317	validation_1-auc:0.660796
# [520]	validation_0-auc:0.819352	validation_1-auc:0.660783
# [521]	validation_0-auc:0.819495	validation_1-auc:0.660675
# [522]	validation_0-auc:0.81965	validation_1-auc:0.660641
# [523]	validation_0-auc:0.819808	validation_1-auc:0.660567
# [524]	validation_0-auc:0.820123	validation_1-auc:0.660658
# [525]	validation_0-auc:0.82023	validation_1-auc:0.66068
# [526]	validation_0-auc:0.820335	validation_1-auc:0.660576
# [527]	validation_0-auc:0.820463	validation_1-auc:0.66027
# [528]	validation_0-auc:0.820609	validation_1-auc:0.660326
# [529]	validation_0-auc:0.820809	validation_1-auc:0.660179
# [530]	validation_0-auc:0.821084	validation_1-auc:0.659955
# [531]	validation_0-auc:0.821158	validation_1-auc:0.660032
# [532]	validation_0-auc:0.821261	validation_1-auc:0.659933
# [533]	validation_0-auc:0.821416	validation_1-auc:0.659959
# [534]	validation_0-auc:0.82156	validation_1-auc:0.659981
# [535]	validation_0-auc:0.821655	validation_1-auc:0.660097
# [536]	validation_0-auc:0.8217	validation_1-auc:0.660101
# [537]	validation_0-auc:0.821809	validation_1-auc:0.660248
# [538]	validation_0-auc:0.82197	validation_1-auc:0.660175
# [539]	validation_0-auc:0.822048	validation_1-auc:0.660214
# [540]	validation_0-auc:0.822085	validation_1-auc:0.660218
# [541]	validation_0-auc:0.822184	validation_1-auc:0.660477
# [542]	validation_0-auc:0.822228	validation_1-auc:0.66058
# [543]	validation_0-auc:0.822371	validation_1-auc:0.660434
# [544]	validation_0-auc:0.822399	validation_1-auc:0.660412
# [545]	validation_0-auc:0.822544	validation_1-auc:0.66044
# [546]	validation_0-auc:0.822561	validation_1-auc:0.660434
# [547]	validation_0-auc:0.822602	validation_1-auc:0.660447
# [548]	validation_0-auc:0.822691	validation_1-auc:0.660662
# [549]	validation_0-auc:0.822729	validation_1-auc:0.66068
# [550]	validation_0-auc:0.82271	validation_1-auc:0.660675
# [551]	validation_0-auc:0.822796	validation_1-auc:0.660749
# [552]	validation_0-auc:0.822828	validation_1-auc:0.660831
# [553]	validation_0-auc:0.822853	validation_1-auc:0.660843
# [554]	validation_0-auc:0.822904	validation_1-auc:0.660649
# [555]	validation_0-auc:0.822985	validation_1-auc:0.660891
# [556]	validation_0-auc:0.823172	validation_1-auc:0.661176
# [557]	validation_0-auc:0.823415	validation_1-auc:0.661154
# [558]	validation_0-auc:0.823562	validation_1-auc:0.661098
# [559]	validation_0-auc:0.823594	validation_1-auc:0.661133
# [560]	validation_0-auc:0.823697	validation_1-auc:0.661115
# [561]	validation_0-auc:0.823847	validation_1-auc:0.661137
# [562]	validation_0-auc:0.824016	validation_1-auc:0.661038
# [563]	validation_0-auc:0.824145	validation_1-auc:0.661107
# [564]	validation_0-auc:0.82427	validation_1-auc:0.661046
# [565]	validation_0-auc:0.824406	validation_1-auc:0.660762
# [566]	validation_0-auc:0.824446	validation_1-auc:0.660654
# [567]	validation_0-auc:0.824483	validation_1-auc:0.660667
# [568]	validation_0-auc:0.824562	validation_1-auc:0.66058
# [569]	validation_0-auc:0.824606	validation_1-auc:0.660593
# [570]	validation_0-auc:0.824711	validation_1-auc:0.660718
# [571]	validation_0-auc:0.824733	validation_1-auc:0.660779
# [572]	validation_0-auc:0.824719	validation_1-auc:0.660822
# [573]	validation_0-auc:0.824812	validation_1-auc:0.660757
# [574]	validation_0-auc:0.824866	validation_1-auc:0.660753
# [575]	validation_0-auc:0.824888	validation_1-auc:0.66071
# [576]	validation_0-auc:0.825011	validation_1-auc:0.660697
# [577]	validation_0-auc:0.82533	validation_1-auc:0.660576
# [578]	validation_0-auc:0.825525	validation_1-auc:0.660481
# Stopping. Best iteration:
# [478]	validation_0-auc:0.814278	validation_1-auc:0.663057
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.02, max_delta_step=0, max_depth=5,
#               min_child_weight=1, min_samples_split=5, missing=None,
#               n_estimators=1000, n_jobs=1, nthread=None,
#               objective='binary:logistic', random_state=31, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#               subsample=1, verbosity=1)

# %%
print("ROC score for Train is:",roc_auc_score(y_train,xgboost.predict_proba(train[selected_features])[:,1]))
print("ROC score for Val is:",roc_auc_score(y_val,xgboost.predict_proba(val[selected_features])[:,1]))
print("ROC score for Test is:",roc_auc_score(y_test,xgboost.predict_proba(test[selected_features])[:,1]))
print("Accuracy score for Train is:",accuracy_score(y_train,xgboost.predict(train[selected_features])))
print("Accuracy score for Val is:",accuracy_score(y_val,xgboost.predict(val[selected_features])))
print("Accuracy score for Test is:",accuracy_score(y_test,xgboost.predict(test[selected_features])))
# Out:
# ROC score for Train is: 0.8142780684508975
# ROC score for Val is: 0.6630568439219071
# ROC score for Test is: 0.6410337904889081
# Accuracy score for Train is: 0.7404635094285303
# Accuracy score for Val is: 0.669
# Accuracy score for Test is: 0.668

# %%
#Selected Feature Importances of the model from Random Forest Classifier
pd.Series(dict(zip(selected_features,xgboost.feature_importances_))).sort_values().plot(kind='barh',figsize=(10,6))

# %%
#Classification report for Test based on RandomForestClassifier
print(classification_report(y_val,rfc.predict(test[selected_features])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.37      0.11      0.17       365
#            1       0.64      0.89      0.74       635
#
#     accuracy                           0.61      1000
#    macro avg       0.50      0.50      0.46      1000
# weighted avg       0.54      0.61      0.53      1000

# %%
#Plotting pdp plot for each of the features
for f in selected_features:

    isolated = pdp_isolate(
    model=xgboost,
    dataset=val[selected_features],
    model_features=selected_features,
    feature=f,
    num_grid_points=100)

    pdp_plot(isolated,feature_name=f,plot_pts_dist=True)

# %%
import shap
explainer = shap.TreeExplainer(xgboost)
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...

# %%
shap.force_plot(explainer.expected_value,explainer.shap_values(X_test.iloc[[2]][selected_features]),X_test.iloc[[2]][selected_features])
# Out:
# <div id='iZS7MPV7163X5MSQDQ75K'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 0.5661510229110718, "outValue": 0.9123171865940094, "link": "identity", "featureNames": ["caseOriginState", "is_adminActionState", "petitionerState", "certReason", "petitioner", "issueArea", "case_reargued", "caseSource", "respondentState", "respondent", "caseSourceState", "case_argued", "is_adminAction", "lcDisposition", "argued_since", "threeJudgeFdc", "lcDisagreement", "caseOrigin"], "features": {"0": {"effect": 0.04748672619462013, "value": -1.0}, "1": {"effect": -0.0007824565400369465, "value": 1.0}, "2": {"effect": 0.026471875607967377, "value": -1.0}, "3": {"effect": 0.12402059137821198, "value": 11.0}, "4": {"effect": 0.2699671685695648, "value": 27.0}, "5": {"effect": 0.05979083478450775, "value": 1.0}, "6": {"effect": 0.000691207533236593, "value": 1.0}, "7": {"effect": 0.060109447687864304, "value": 29.0}, "8": {"effect": 0.044316601008176804, "value": -1.0}, "9": {"effect": 0.04213128611445427, "value": 106.0}, "10": {"effect": -0.005305666476488113, "value": -1.0}, "11": {"effect": -0.10398899763822556, "value": 0.0}, "12": {"effect": -0.043290939182043076, "value": 1.0}, "13": {"effect": -0.046957775950431824, "value": 4.0}, "14": {"effect": -0.01616636849939823, "value": 101.0}, "15": {"effect": -0.0004588609444908798, "value": 0.0}, "16": {"effect": -0.11298415809869766, "value": 0.0}, "17": {"effect": 0.0011156370164826512, "value": 9999.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iZS7MPV7163X5MSQDQ75K')
#   );
# </script>

# %%
shap.force_plot(explainer.expected_value,explainer.shap_values(X_test.iloc[[3]][selected_features]),X_test.iloc[[3]][selected_features])
# Out:
# <div id='iYCITZ9V67J2LON2IKQXT'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 0.5661720633506775, "outValue": -0.08765196800231934, "link": "identity", "featureNames": ["caseOriginState", "is_adminActionState", "petitionerState", "certReason", "petitioner", "issueArea", "case_reargued", "caseSource", "respondentState", "respondent", "caseSourceState", "case_argued", "is_adminAction", "lcDisposition", "argued_since", "threeJudgeFdc", "lcDisagreement", "caseOrigin"], "features": {"0": {"effect": 0.02942090667784214, "value": -1.0}, "1": {"effect": -0.0018052106024697423, "value": 1.0}, "2": {"effect": 0.0171858761459589, "value": -1.0}, "3": {"effect": -0.2539847493171692, "value": 2.0}, "4": {"effect": -0.3292132318019867, "value": 215.0}, "5": {"effect": 0.0752892717719078, "value": 1.0}, "6": {"effect": 0.00015230078133754432, "value": 1.0}, "7": {"effect": -0.04389466717839241, "value": 26.0}, "8": {"effect": 0.12702344357967377, "value": 27.0}, "9": {"effect": -0.09968382865190506, "value": 19.0}, "10": {"effect": -0.0004906498943455517, "value": -1.0}, "11": {"effect": -0.04232556372880936, "value": 0.0}, "12": {"effect": 0.010952451266348362, "value": 1.0}, "13": {"effect": -0.05542406812310219, "value": 2.0}, "14": {"effect": -0.02840670570731163, "value": 84.0}, "15": {"effect": -0.007463168818503618, "value": 0.0}, "16": {"effect": -0.04929674044251442, "value": 0.0}, "17": {"effect": -0.0018597505986690521, "value": 81.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iYCITZ9V67J2LON2IKQXT')
#   );
# </script>

# %%
selected_features
# Out:
# ['caseOriginState',
#  'is_adminActionState',
#  'petitionerState',
#  'certReason',
#  'petitioner',
#  'issueArea',
#  'case_reargued',
#  'caseSource',
#  'respondentState',
#  'respondent',
#  'caseSourceState',
#  'case_argued',
#  'is_adminAction',
#  'lcDisposition',
#  'argued_since',
#  'threeJudgeFdc',
#  'lcDisagreement',
#  'caseOrigin']

# %%
fig = shap.force_plot(explainer.expected_value,explainer.shap_values(X_test.iloc[[3]][selected_features]),X_test.iloc[[3]][selected_features])

# %%
perm_xgboost = PermutationImportance(xgboost, random_state=1,scoring='roc_auc').fit(X_val[selected_features], y_val)
eli5.show_weights(perm_xgboost,feature_names=selected_features,top=None)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0264
#
#                     &plusmn; 0.0145
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 certReason
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0177
#
#                     &plusmn; 0.0161
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 petitioner
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.22%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0155
#
#                     &plusmn; 0.0087
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 respondent
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0143
#
#                     &plusmn; 0.0122
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lcDisposition
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.42%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0136
#
#                     &plusmn; 0.0089
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 issueArea
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0130
#
#                     &plusmn; 0.0046
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 argued_since
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.27%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0123
#
#                     &plusmn; 0.0142
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lcDisagreement
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.90%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0099
#
#                     &plusmn; 0.0079
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 caseOriginState
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.63%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0089
#
#                     &plusmn; 0.0072
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 caseSourceState
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0086
#
#                     &plusmn; 0.0051
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 petitionerState
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0066
#
#                     &plusmn; 0.0063
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 respondentState
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.66%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0063
#
#                     &plusmn; 0.0115
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 caseSource
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.50%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0053
#
#                     &plusmn; 0.0081
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 case_argued
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.98%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0027
#
#                     &plusmn; 0.0034
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 is_adminAction
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0023
#
#                     &plusmn; 0.0030
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 caseOrigin
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 threeJudgeFdc
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 case_reargued
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 96.97%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0018

# %%
X_train[selected_features].nunique()
# Out:
# caseOriginState         53
# is_adminActionState      2
# petitionerState         57
# certReason              13
# petitioner              16
# issueArea               14
# case_reargued            2
# caseSource              34
# respondentState         56
# respondent              16
# caseSourceState         53
# case_argued              2
# is_adminAction           2
# lcDisposition           13
# argued_since           353
# threeJudgeFdc            3
# lcDisagreement           3
# caseOrigin              35
# dtype: int64

# %%
isolated = pdp_isolate(
    model=xgboost,
    dataset=val[selected_features],
    model_features=selected_features,
    feature='argued_since',
    num_grid_points=100)
fig = pdp_plot(isolated,feature_name='argued_since',plot_pts_dist=True)

# %%
len(features),len(selected_features)
# Out:
# (20, 18)

# %%
from sklearn.metrics import roc_curve

# %%
thresholds,truepositive,falsepositive = roc_curve(y_test,xgboost.predict_proba(X_test[selected_features])[:,1])

# %%
falsepositive,truepositive,thresholds = roc_curve(y_test,xgboost.predict_proba(X_test[selected_features])[:,1])

# %%
plt.scatter(thresholds,truepositive)
plt.scatter(thresholds,falsepositive)

# %%
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(10,10),dpi=300)
plt.scatter(falsepositive,truepositive)
plt.title('ROC Curve', fontweight = 'bold', fontsize = 40)
plt.xlabel('False Positive Rate', fontsize = 35)
plt.ylabel('True Positive Rate', fontsize = 35)
# Out:
# Text(0, 0.5, 'True Positive Rate')

# %%
#getting a test value for generating shap value
shaprow = X_test[selected_features].sample(1,random_state=5)
print("The probability of winning the case is ",xgboost.predict_proba(shaprow))
# Out:
# The probability of winning the case is  [[0.60598695 0.39401305]]

# %%
#Generating the shapvalue for the selected test row
shap.force_plot(explainer.expected_value,explainer.shap_values(shaprow),shaprow)
# Out:
# <div id='iQYEGUH39DTUGTYNCFA52'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 0.5661720633506775, "outValue": -0.43047410249710083, "link": "identity", "featureNames": ["caseOriginState", "is_adminActionState", "petitionerState", "certReason", "petitioner", "issueArea", "case_reargued", "caseSource", "respondentState", "respondent", "caseSourceState", "case_argued", "is_adminAction", "lcDisposition", "argued_since", "threeJudgeFdc", "lcDisagreement", "caseOrigin"], "features": {"0": {"effect": 0.02369854412972927, "value": -1.0}, "1": {"effect": -0.00023233167303260416, "value": 1.0}, "2": {"effect": 0.0005549294874072075, "value": -1.0}, "3": {"effect": -0.3656601011753082, "value": 2.0}, "4": {"effect": -0.3744237422943115, "value": 126.0}, "5": {"effect": 0.10569003969430923, "value": 1.0}, "6": {"effect": 0.00032745939097367227, "value": 1.0}, "7": {"effect": 0.09875768423080444, "value": 29.0}, "8": {"effect": -0.032534267753362656, "value": -1.0}, "9": {"effect": -0.2645292282104492, "value": 27.0}, "10": {"effect": -0.03500792756676674, "value": -1.0}, "11": {"effect": -0.04329894855618477, "value": 0.0}, "12": {"effect": 0.035583484917879105, "value": 1.0}, "13": {"effect": -0.0554729588329792, "value": 2.0}, "14": {"effect": -0.17623309791088104, "value": 164.0}, "15": {"effect": -0.005859486758708954, "value": 0.0}, "16": {"effect": 0.1367570012807846, "value": 1.0}, "17": {"effect": -0.044763192534446716, "value": 50.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iQYEGUH39DTUGTYNCFA52')
#   );
# </script>

# %%
#Now, lets see the predicted probablit when the certReason is changed to 10
shaprow['certReason']=10
print("The probability of winning the case is ",xgboost.predict_proba(shaprow))
# Out:
# The probability of winning the case is  [[0.4303348 0.5696652]]

# %%
shap.force_plot(explainer.expected_value,explainer.shap_values(shaprow),shaprow)
# Out:
# <div id='iIL4J8BE4ITCUQVHK0SK6'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 0.5661720633506775, "outValue": 0.28048640489578247, "link": "identity", "featureNames": ["caseOriginState", "is_adminActionState", "petitionerState", "certReason", "petitioner", "issueArea", "case_reargued", "caseSource", "respondentState", "respondent", "caseSourceState", "case_argued", "is_adminAction", "lcDisposition", "argued_since", "threeJudgeFdc", "lcDisagreement", "caseOrigin"], "features": {"0": {"effect": 0.026763886213302612, "value": -1.0}, "1": {"effect": -0.0005140291759744287, "value": 1.0}, "2": {"effect": -0.001978222979232669, "value": -1.0}, "3": {"effect": 0.23609772324562073, "value": 10.0}, "4": {"effect": -0.31830286979675293, "value": 126.0}, "5": {"effect": 0.09564380347728729, "value": 1.0}, "6": {"effect": 0.0004949862486682832, "value": 1.0}, "7": {"effect": 0.08052478730678558, "value": 29.0}, "8": {"effect": -0.005092322360724211, "value": -1.0}, "9": {"effect": -0.20945684611797333, "value": 27.0}, "10": {"effect": -0.05011146888136864, "value": -1.0}, "11": {"effect": -0.09964336454868317, "value": 0.0}, "12": {"effect": 0.031747836619615555, "value": 1.0}, "13": {"effect": -0.0839863047003746, "value": 2.0}, "14": {"effect": -0.1949625462293625, "value": 164.0}, "15": {"effect": -0.0023413831368088722, "value": 0.0}, "16": {"effect": 0.18181540071964264, "value": 1.0}, "17": {"effect": 0.027615252882242203, "value": 50.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iIL4J8BE4ITCUQVHK0SK6')
#   );
# </script>

# %%
#ax.savefig('../assets/partialplot',dpi=172)
